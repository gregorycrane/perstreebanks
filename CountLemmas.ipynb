# %%
import re

lemmas = 0
def countrefs(fname):
    quotes = 0
    bibls = 0
    global lemmas
    f = open(fname)
    for l in f:
        res = re.subn('<quote','',l)
        quotes = quotes + res[1]
        res = re.subn('<foreign[^>]+>[^<]+\s','',l)
        quotes = quotes + res[1]
        res = re.subn('<lemma','',l)
        quotes = quotes + res[1]
        lemmas = lemmas + res[1]
        res = re.subn('<bibl ','',l)
        bibls = bibls + res[1]
    print(fname,quotes,bibls)
    f.close()
    return(quotes,bibls)

quotes = 0
bibls = 0
a,b = countrefs('/Users/gcrane/Desktop/OldMacintoshHD/sgml/texts/LSJ/lsj.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/SlaterPindar/cunliffe.lexentries.unicode.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/SlaterPindar/cunliffe.hompers.unicode.list.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/slater.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/Desktop/OldMacintoshHD/sgml/texts/Lewis/ls.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/smyth_eng.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/kg.gram1_ger.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/kg.gram2_ger.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/kg.gram3_ger.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/goodwin.moods_eng.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/gildersleeve_eng.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/lindsay_syntax.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/autenrieth.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/Desktop/OldMacintoshHD/sgml/texts/Classics/Allen_and_Greenough/copyright/ag.gram_eng.xml')

quotes = quotes + a
bibls = bibls + b

# Realia
a,b = countrefs('/Users/gcrane/github/canonical-pdlrefwk/data/viaf88890045/001/viaf88890045.001.xml')
quotes = quotes + a
bibls = bibls + b

# Geo
a,b = countrefs('/Users/gcrane/github/canonical-pdlrefwk/data/viaf88890045/002/viaf88890045.002.xml')
quotes = quotes + a
bibls = bibls + b


# Bio
a,b = countrefs('/Users/gcrane/github/canonical-pdlrefwk/data/viaf88890045/003/viaf88890045.003.perseus-eng1.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/harper.xml')
quotes = quotes + a
bibls = bibls + b



## Commentaries

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/goodwin.crown.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/sandys.private.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/how.hdt.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/macan.hdt.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/benner.hom.il_eng.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/leaf.hom.il_eng.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/seymour.hom.il1-3.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/seymour.hom.il4-6.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/allen.hh_eng.xml')
quotes = quotes + a
bibls = bibls + b


a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/adam.plat.prot_eng.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/adam.rep.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/lodge.plat.gorg_eng.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/bury.symp.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/towle.plat.prot_eng.xml')
quotes = quotes + a
bibls = bibls + b


a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/jebb.soph.aj_eng.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/jebb.soph.ant_eng.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/jebb.soph.el_eng.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/jebb.soph.oc_eng.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/jebb.soph.ot_eng.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/jebb.soph.phil_eng.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/jebb.soph.trach_eng.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/marchant.thuc1_eng.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/morris.thuc1_eng.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/marchant.thuc2_eng.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/marchant.thuc3_eng.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/graves.thuc4_eng.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/graves.thuc5_eng.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/fowler.thuc5_eng.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/marchant.thuc6_eng.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/marchant.thuc7_eng.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/smith.thuc3_eng.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/smith.thuc6_eng.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/smith.thuc7_eng.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/tucker.thuc8_eng.xml')
quotes = quotes + a
bibls = bibls + b

a,b = countrefs('/Users/gcrane/github/PerseusCommentaries/smith.mem_eng.xml')
quotes = quotes + a
bibls = bibls + b

print('lemmas',lemmas,'quotes',quotes,'bibs',bibls)
# Out:
# /Users/gcrane/Desktop/OldMacintoshHD/sgml/texts/LSJ/lsj.xml 248588 438782
# /Users/gcrane/github/SlaterPindar/cunliffe.lexentries.unicode.xml 20404 92931
# /Users/gcrane/github/SlaterPindar/cunliffe.hompers.unicode.list.xml 403 6209
# /Users/gcrane/github/PerseusCommentaries/slater.xml 36371 21377
# /Users/gcrane/Desktop/OldMacintoshHD/sgml/texts/Lewis/ls.xml 225213 309021
# /Users/gcrane/github/PerseusCommentaries/smyth_eng.xml 15754 5923
# /Users/gcrane/github/PerseusCommentaries/kg.gram1_ger.xml 11619 2856
# /Users/gcrane/github/PerseusCommentaries/kg.gram2_ger.xml 19301 10832
# /Users/gcrane/github/PerseusCommentaries/kg.gram3_ger.xml 16311 7902
# /Users/gcrane/github/PerseusCommentaries/goodwin.moods_eng.xml 7786 4966
# /Users/gcrane/github/PerseusCommentaries/gildersleeve_eng.xml 5342 1910
# /Users/gcrane/github/PerseusCommentaries/lindsay_syntax.xml 3347 2811
# /Users/gcrane/github/PerseusCommentaries/autenrieth.xml 3719 10085
# ...

# %%
# Importing re module
import re

# Given String
s = "I am a human being."

# Performing the subn() operation
res_1 = re.subn('a', 'x', s)
res_2 = re.subn('[a,I]','x',s)

# Print Results
print(res_1[1])
print(res_2)
# Out:
# 3
# ('x xm x humxn being.', 4)

# %%
import re
totbibs = 0

def countbibs(fname):
    global totbibs
    f = open(fname)
    for l in f:
        l,n = re.subn('<bibl ',' ',l)
        totbibs = n + totbibs
    f.close()
    
    # Geo
countbibs('/Users/gcrane/github/canonical-pdlrefwk/data/viaf88890045/002/viaf88890045.002.xml')


# Bio
countbibs('/Users/gcrane/github/canonical-pdlrefwk/data/viaf88890045/003/viaf88890045.003.perseus-eng1.xml')

    
countbibs('/Users/gcrane/Desktop/OldMacintoshHD/sgml/texts/Classics/Encyclopedia/copyright/encyclopedia.xml')
print(totbibs)
# Out:
# 102491
