# %% [markdown]
# # Diachronic Analysis of Classical Greek Corpora
#
# This notebook analyzes texts from two open-source Greek literature repositories:
#
# - **[PerseusDL/canonical-greekLit](https://github.com/PerseusDL/canonical-greekLit)** — canonical Greek literary tradition
# - **[OpenGreekAndLatin/First1KGreek](https://github.com/OpenGreekAndLatin/First1KGreek)** — the first thousand years of Greek
#
# Both contain TEI XML files organized by CTS URNs. We extract Greek-language texts,
# classify them by century and genre (prose vs. poetry), and visualize the distribution.

# %% [markdown]
# ## 1. Setup and Dependencies

# %%
import os
import re
import glob
import subprocess
from collections import defaultdict
from pathlib import Path

from lxml import etree
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np

# Plotting style
plt.rcParams.update({
    'figure.figsize': (14, 6),
    'figure.dpi': 120,
    'font.family': 'serif',
    'font.size': 11,
    'axes.spines.top': False,
    'axes.spines.right': False,
    'axes.grid': True,
    'grid.alpha': 0.3,
})

# %% [markdown]
# ## 2. Clone the Repositories
#
# Shallow clones to save time and disk space. Skip if directories already exist.

# %%
REPOS = {
    'perseus': {
        'url': 'https://github.com/PerseusDL/canonical-greekLit.git',
        'dir': '/Users/gcrane/github/canonical-greekLit',
    },
    'first1k': {
        'url': 'https://github.com/OpenGreekAndLatin/First1KGreek.git',
        'dir': '/Users/gcrane/github/First1KGreek',
    },
}

for name, info in REPOS.items():
    if not os.path.isdir(info['dir']):
        print(f"Cloning {name}...")
        subprocess.run(
            ['git', 'clone', '--depth', '1', info['url'], info['dir']],
            check=True,
        )
        print(f"  Done: {info['dir']}")
    else:
        print(f"Already present: {info['dir']}")
# Out:
# Already present: /Users/gcrane/github/canonical-greekLit
# Already present: /Users/gcrane/github/First1KGreek

# %% [markdown]
# ## 3. TLG-to-Century Mapping
#
# The Thesaurus Linguae Graecae (TLG) assigns each author a four-digit code.
# Both repos use these as directory names (e.g. `tlg0012` = Homer).
#
# Below is a curated lookup table mapping TLG author numbers to approximate
# floruit centuries. Negative values = BCE. This covers the major authors in
# both corpora; unknown authors will be tagged for manual review.
#
# **Sources:** TLG Canon (Berkowitz & Squitier), Perseus Catalog, OCD entries.

# %%
# Mapping: TLG author number -> approximate floruit century
# Negative = BCE, Positive = CE
# This is a representative subset; extend as needed.

TLG_CENTURY = {
    # ---- Archaic period (8th–6th c. BCE) ----
    '0012': -8,   # Homer
    '0020': -7,   # Hesiod
    '0214': -7,   # Archilochus
    '0261': -7,   # Callinus
    '0260': -7,   # Tyrtaeus
    '0263': -7,   # Mimnermus
    '0262': -7,   # Semonides
    '0264': -6,   # Solon
    '0258': -6,   # Theognis
    '0009': -6,   # Sappho
    '0259': -6,   # Alcaeus
    '0265': -6,   # Stesichorus
    '0253': -6,   # Ibycus
    '0254': -6,   # Anacreon
    '0255': -5,   # Simonides
    '0033': -6,   # Pindar (early 5th but archaic tradition)
    '1220': -6,   # Aesop / Aesopic fables

    # ---- Classical period (5th–4th c. BCE) ----
    '0033': -5,   # Pindar (reassign to 5th)
    '0085': -5,   # Aeschylus
    '0011': -5,   # Sophocles
    '0006': -5,   # Euripides
    '0019': -5,   # Aristophanes
    '0013': -5,   # Bacchylides
    '0016': -5,   # Herodotus
    '0003': -5,   # Thucydides
    '0627': -5,   # Hippocrates / Hippocratic corpus
    '0081': -5,   # Antiphon (orator)
    '0026': -5,   # Andocides
    '0540': -5,   # Democritus
    '0527': -5,   # Empedocles
    '0086': -4,   # Lysias
    '0029': -4,   # Isocrates
    '0014': -4,   # Demosthenes
    '0028': -4,   # Aeschines (orator)
    '0030': -4,   # Hyperides
    '0032': -4,   # Lycurgus (orator)
    '0010': -4,   # Isaeus
    '0017': -4,   # Dinarchus
    '0059': -4,   # Plato
    '0086': -4,   # Lysias
    '0007': -4,   # Xenophon
    '0543': -4,   # Aristotle (some works span 4th c.)
    '0086': -4,   # Aristotle

    # ---- Hellenistic period (3rd–1st c. BCE) ----
    '0533': -3,   # Theophrastus
    '0541': -3,   # Epicurus
    '0553': -3,   # Menander
    '0533': -3,   # Theophrastus
    '0058': -3,   # Callimachus
    '0005': -3,   # Theocritus
    '0001': -3,   # Apollonius Rhodius
    '0004': -3,   # Aratus
    '0557': -2,   # Polybius
    '0613': -2,   # Diodorus Siculus (some put him in 1st BCE)
    '0613': -1,   # Diodorus Siculus
    '0008': -1,   # Athenaeus (sometimes 2nd/3rd CE, but TLG 0008 varies)
    '0099': -1,   # Dionysius of Halicarnassus
    '0057': -1,   # Posidonius
    '0093': -1,   # Philodemus

    # ---- Early Roman Imperial (1st–2nd c. CE) ----
    '0062': 1,    # Strabo
    '0527': 1,    # Philo of Alexandria (spans 1st BCE/CE)
    '0526': 1,    # Josephus
    '0007': -4,   # Xenophon (already set above)
    '0031': 1,    # Dio Chrysostom
    '0087': 1,    # Epictetus (via Arrian)
    '0046': 2,    # Plutarch
    '0018': 2,    # Appian
    '0363': 2,    # Ptolemy
    '0060': 2,    # Pausanias
    '0008': 2,    # Athenaeus (reassign to 2nd/3rd CE)
    '0034': 2,    # Lucian
    '0006': -5,   # Euripides (already set)
    '0527': 1,    # Philo (already set)
    '0556': 2,    # Artemidorus
    '0058': -3,   # Callimachus (already set)
    '0059': -4,   # Plato (already set)
    '0061': 2,    # Galen
    '0086': -4,   # Lysias (already set)
    '0090': 2,    # Arrian
    '0094': 2,    # Aelius Aristides
    '0007': -4,   # Xenophon (already set)
    '0535': 2,    # Marcus Aurelius
    '0525': 2,    # Aelian
    '0088': 2,    # Achilles Tatius
    '0032': -4,   # Lycurgus already set
    '0551': 2,    # Longus

    # ---- Later Imperial / Late Antique (3rd–5th c. CE) ----
    '0555': 3,    # Cassius Dio
    '0093': -1,   # Philodemus (already set)
    '2022': 3,    # Origen
    '2040': 3,    # Eusebius
    '2018': 3,    # Clement of Alexandria
    '2042': 4,    # John Chrysostom
    '2017': 4,    # Basil of Caesarea
    '2022': 3,    # Origen (already set)
    '2023': 3,    # Hippolytus
    '4089': 4,    # Gregory of Nazianzus
    '4090': 4,    # Gregory of Nyssa
    '2062': 4,    # Athanasius
    '5000': 5,    # Nonnus of Panopolis
    '2934': 5,    # Proclus
    '4015': 5,    # Stobaeus
    '0032': -4,   # already set
    '2959': 5,    # Simplicius
## more additions

    # ---- Hellenistic Period (3rd c. BCE) ----
    '0552': -3,    # Archimedes
    
    # ---- Roman Period (1st–3rd c. CE) ----
    '0559': 1,     # Hero of Alexandria
    '1271': 1,     # Clemens Romanus
    '0074': 2,     # Arrian
    '0563': 2,     # Maximus of Tyre
    '0592': 2,     # Hermogenes
    '0615': 2,     # Aspasius
    '0616': 2,     # Polyaenus
    '1764': 2,     # Vettius Valens
    '0638': 3,     # Philostratus the Athenian
    '0658': 3,     # Heliodorus of Emesa
    '2034': 3,     # Porphyry (Porphyrius)
    
    # ---- Late Antiquity (4th–7th c. CE) ----
    '2003': 4,     # Julian the Emperor
    '2035': 4,     # Athanasius
    '2045': 5,     # Nonnus of Panopolis
    '2048': 5,     # Sozomenus, Salaminius Hermias
    '2057': 5,     # Socrates Scholasticus
    '4017': 5,     # Syrianus
    '4020': 6,     # Elias Neoplatonicus
    '4021': 6,     # David the Invincible
    '4024': 6,     # Agathias Scholasticus
    '2371': 7,     # Chronicon Paschale
    
    # ---- Byzantine Period (11th–14th c. CE) ----
    '4034': 11,    # Michael of Ephesus
    '4030': 13,    # Sophonias
    
    # ---- Collective / Spurious / Unknown (NA) ----
    '0530': 'NA',  # Pseudo-Galen
    '4026': 'NA',  # Anonymi in Aristotelis Artem Rhetoricam
    '4033': 'NA',  # Anonymi In Aristotelis Ethica Nicomachea
    '5037': 'NA',  # Scholia in Sophoclem
    '7000': 'NA',  # Greek Anthology
}

# Deduplicated final mapping (last assignment wins above,
# so let's be explicit about the canonical values):
TLG_CENTURY_CLEAN = {
    '0012': -8, '0020': -7, '0214': -7, '0261': -7, '0260': -7,
    '0263': -7, '0262': -7, '0264': -6, '0258': -6, '0009': -6,
    '0259': -6, '0265': -6, '0253': -6, '0254': -6, '0255': -5,
    '1220': -6,
    '0033': -5, '0085': -5, '0011': -5, '0006': -5, '0019': -5,
    '0013': -5, '0016': -5, '0003': -5, '0627': -5, '0081': -5,
    '0026': -5, '0540': -5,
    '0086': -4, '0029': -4, '0014': -4, '0028': -4, '0030': -4,
    '0032': -4, '0010': -4, '0017': -4, '0059': -4, '0007': -4,
    '0543': -4,
    '0533': -3, '0541': -3, '0553': -3, '0058': -3, '0005': -3,
    '0001': -3, '0004': -3,
    '0557': -2, '0613': -1, '0099': -1, '0057': -1, '0093': -1,
    '0062':  1, '0527':  1, '0526':  1, '0031':  1, '0087':  1,
    '0046':  2, '0018':  2, '0363':  2, '0060':  2, '0008':  2,
    '0034':  2, '0556':  2, '0061':  2, '0090':  2, '0094':  2,
    '0535':  2, '0525':  2, '0088':  2, '0551':  2,
    '0555':  3, '2022':  3, '2040':  3, '2018':  3, '2023':  3,
    '2042':  4, '2017':  4, '4089':  4, '4090':  4, '2062':  4,
    '5000':  5, '2934':  5, '4015':  5, '2959':  5,
#}
# for simplicity just add this to the previous dictionary
#TLG_Century_est = {
    '0732': 3,    # Alexander of Aphrodisias (14 files, 1,249,457 words)
    '4013': 6,    # Simplicius (4 files, 1,140,771 words)
    '4102': 8,    # Catenae (Novum Testamentum) (32 files, 1,139,622 words) - compiled approx 6th-10th c.
    '5026': 10,   # Scholia in Homerum (2 files, 946,337 words) - Venetus A is 10th c.
    '2200': 4,    # Libanius (103 files, 715,749 words)
    '9010': 10,   # Suda (1 files, 583,818 words)
    '3135': 12,   # Joannes Zonaras (4 files, 467,911 words)
    '5023': 12,   # Scholia in Euripidem (8 files, 426,561 words) - mostly 11th-12th c.
    '0284': 2,    # Aelius Aristides (56 files, 321,227 words)
    '4016': 5,    # Ammonius (5 files, 289,666 words)
    '2021': 4,    # Epiphanius (3 files, 287,269 words)
    '2001': 4,    # Themistius (5 files, 285,061 words)
    '4031': 12,   # Eustratius (1 files, 264,213 words)
    '4029': 6,    # Procopius (2 files, 256,794 words)
    '1799': -3,   # Euclid (13 files, 244,566 words)
    '0544': 2,    # Sextus Empiricus (2 files, 221,578 words)
    '2000': 3,    # Plotinus (1 files, 214,015 words)
    '0082': 2,    # Apollonius Dyscolus (4 files, 202,634 words)
    '0385': 3,    # Cassius Dio Cocceianus (1 files, 191,358 words)
    '4018': 6,    # Asclepius (1 files, 190,402 words)
    '4019': 6,    # Olympiodorus (3 files, 184,977 words)
    '0612': 1,    # Dio Chrysostom (1 files, 178,358 words)
    '4036': 5,    # Proclus Diadochus (1 files, 175,197 words)
    '0656': 1,    # Dioscurides Pedianus (1 files, 170,756 words)
    '2703': 12,   # Anna Comnena (1 files, 162,386 words)
    '2115': 3,    # Hippolytus (2 files, 159,635 words)
    '0545': 3,    # Aelian (4 files, 157,254 words)
    '5034': 12,   # Scholia in Pindarum (3 files, 151,612 words) - often 12th c.
    '2703': 12,   # Annae Comnenae (1 files, 150,778 words)
    '1264': -3,   # Chrysippus (4 files, 148,150 words)
}
print(f"Mapped {len(TLG_CENTURY_CLEAN)} TLG author codes to centuries.")
# Out:
# Mapped 113 TLG author codes to centuries.

# %% [markdown]
# ## 4. TEI XML Parsing Functions
#
# Each XML file in these repos follows the CapiTainS/CTS convention:
# - Files are named like `tlg0012.tlg001.perseus-grc2.xml`
# - Only files with `-grc` in the filename contain Greek text (others are translations)
# - Poetry is marked with `<l>` (verse line) elements
# - Prose is marked with `<p>` (paragraph) elements
# - The citation structure in `<refsDecl>` tells us the hierarchy (book/chapter/line vs. book/chapter/section)

# %%
# TEI and CTS namespaces used in these files
NS = {
    'tei': 'http://www.tei-c.org/ns/1.0',
    'ti': 'http://chs.harvard.edu/xmlns/cts',
}


def extract_tlg_code(filepath):
    """Extract the 4-digit TLG author code from a filepath.
    
    Paths look like: .../data/tlg0012/tlg001/tlg0012.tlg001.perseus-grc2.xml
    We want '0012' from the directory name 'tlg0012'.
    """
    parts = Path(filepath).parts
    for part in parts:
        m = re.match(r'tlg(\d{4})', part, re.IGNORECASE)
        if m:
            return m.group(1)
    return None


def is_greek_edition(filepath: str) -> bool:
    """Check if a file is a Greek-language edition (not a translation)."""
    fname = os.path.basename(filepath).lower()
    return '-grc' in fname and fname.endswith('.xml')


def classify_genre(tree: etree._ElementTree) -> str:
    """Classify a TEI XML document as 'poetry', 'prose', or 'mixed'.
    
    Strategy:
    1. Count <l> elements (verse lines) and <p> elements (paragraphs)
       inside the <body> or <text> of the document.
    2. Also check the refsDecl citation scheme — if the deepest
       cRefPattern references 'line' or 'l[@n', it's likely poetry.
    3. If verse lines dominate (>60% of structural elements), classify
       as poetry; if paragraphs dominate, classify as prose; otherwise mixed.
    """
    root = tree.getroot()
    
    # Try with TEI namespace first, then without (older files)
    for ns_prefix in ['{http://www.tei-c.org/ns/1.0}', '']:
        l_elements = root.findall(f'.//{ns_prefix}l')
        p_elements = root.findall(f'.//{ns_prefix}p')
        # Filter out <p> inside teiHeader (those are metadata, not text)
        header_tag = f'{ns_prefix}teiHeader'
        p_in_body = [
            p for p in p_elements
            if not any(anc.tag == header_tag for anc in p.iterancestors())
        ]
        
        n_lines = len(l_elements)
        n_paras = len(p_in_body)
        
        if n_lines + n_paras > 0:
            break
    
    # Also check citation scheme for 'line' patterns
    refs_text = ''
    for ns_prefix in ['{http://www.tei-c.org/ns/1.0}', '']:
        for refs in root.iter(f'{ns_prefix}refsDecl'):
            refs_text += etree.tostring(refs, encoding='unicode')
    
    has_line_citation = bool(re.search(r'line|/l\[|verse', refs_text, re.IGNORECASE))
    
    total = n_lines + n_paras
    if total == 0:
        # Fallback: check citation scheme
        return 'poetry' if has_line_citation else 'prose'
    
    line_ratio = n_lines / total
    
    if line_ratio > 0.6 or (line_ratio > 0.3 and has_line_citation):
        return 'poetry'
    elif line_ratio < 0.2:
        return 'prose'
    else:
        return 'mixed'


def count_greek_words(tree: etree._ElementTree) -> int:
    """Count approximate Greek words in the text body.
    
    Extracts all text content from <body> (or <text>),
    filters for lines containing Greek Unicode characters,
    and counts whitespace-delimited tokens.
    """
    root = tree.getroot()
    
    # Find the body element
    body = None
    for ns_prefix in ['{http://www.tei-c.org/ns/1.0}', '']:
        body = root.find(f'.//{ns_prefix}body')
        if body is not None:
            break
    
    if body is None:
        # Try the whole <text> element
        for ns_prefix in ['{http://www.tei-c.org/ns/1.0}', '']:
            body = root.find(f'.//{ns_prefix}text')
            if body is not None:
                break
    
    if body is None:
        return 0
    
    # Extract all text content
    all_text = ''.join(body.itertext())
    
    # Filter to lines with Greek characters (U+0370-U+03FF, U+1F00-U+1FFF)
    greek_pattern = re.compile(r'[\u0370-\u03FF\u1F00-\u1FFF]')
    words = all_text.split()
    greek_words = [w for w in words if greek_pattern.search(w)]
    
    return len(greek_words)


def extract_author_name(tree: etree._ElementTree) -> str:
    """Try to extract author name from the TEI header."""
    root = tree.getroot()
    for ns_prefix in ['{http://www.tei-c.org/ns/1.0}', '']:
        author = root.find(f'.//{ns_prefix}author')
        if author is not None and author.text:
            return author.text.strip()
    return 'Unknown'

# %% [markdown]
# ## 5. Scan Both Repositories
#
# Walk through all XML files, keeping only Greek-language editions.
# For each file, record: author code, century, genre, word count, source repo.

# %%
def scan_repo(repo_dir, repo_label):
    """Scan a repository and extract metadata for each Greek text."""
    data_dir = os.path.join(repo_dir, 'data')
    if not os.path.isdir(data_dir):
        print(f"  Warning: no data/ directory in {repo_dir}")
        return []
    
    xml_files = glob.glob(os.path.join(data_dir, '**', '*.xml'), recursive=True)
    print(f"  Found {len(xml_files)} total XML files in {repo_label}")
    
    # Filter to Greek editions only
    greek_files = [f for f in xml_files if is_greek_edition(f)]
    print(f"  Of which {len(greek_files)} are Greek-language editions")
    
    records = []
    errors = 0
    
    for i, filepath in enumerate(greek_files):
        if (i + 1) % 100 == 0:
            print(f"    Processing {i+1}/{len(greek_files)}...")
        
        try:
            tree = etree.parse(filepath)
        except etree.XMLSyntaxError:
            errors += 1
            continue
        
        tlg_code = extract_tlg_code(filepath)
        if tlg_code is None:
            continue
        
        century = TLG_CENTURY_CLEAN.get(tlg_code)
        genre = classify_genre(tree)
        word_count = count_greek_words(tree)
        author = extract_author_name(tree)
        
        records.append({
            'file': os.path.basename(filepath),
            'repo': repo_label,
            'tlg_code': tlg_code,
            'author': author,
            'century': century,
            'genre': genre,
            'word_count': word_count,
        })
    
    if errors:
        print(f"  Skipped {errors} files with XML parse errors")
    
    return records


print("Scanning Perseus canonical-greekLit...")
perseus_records = scan_repo('/Users/gcrane/github/canonical-greekLit', 'Perseus')

print("\nScanning First1KGreek...")
first1k_records = scan_repo('/Users/gcrane/github/First1KGreek', 'First1KGreek')

# Combine
all_records = perseus_records + first1k_records
df = pd.DataFrame(all_records)

print(f"\nTotal records: {len(df)}")
print(f"  With known century: {df['century'].notna().sum()}")
print(f"  With unknown century: {df['century'].isna().sum()}")
print(f"\nGenre distribution:")
print(df['genre'].value_counts().to_string())
# Out:
# Scanning Perseus canonical-greekLit...
#   Found 2504 total XML files in Perseus
#   Of which 815 are Greek-language editions
#     Processing 100/815...
#     Processing 200/815...
#     Processing 300/815...
#     Processing 400/815...
#     Processing 500/815...
#     Processing 600/815...
#     Processing 700/815...
#     Processing 800/815...
#   Skipped 1 files with XML parse errors
#
# Scanning First1KGreek...
#   Found 2613 total XML files in First1KGreek
#   Of which 1124 are Greek-language editions
#     Processing 100/1124...
#     Processing 200/1124...
#     Processing 300/1124...
#     Processing 400/1124...
#     Processing 500/1124...
#     Processing 600/1124...
#     Processing 700/1124...
#     Processing 800/1124...
#     Processing 900/1124...
#     Processing 1000/1124...
#     Processing 1100/1124...
#
# Total records: 1932
#   With known century: 1452
#   With unknown century: 480
#
# Genre distribution:
# prose     1612
# poetry     198
# mixed      122

# %% [markdown]
# ## 6. Data Cleaning
#
# Filter to texts with known century assignments and nonzero word counts.
# Create human-readable century labels.

# %%
# Filter to dated texts with actual content
df_dated = df.dropna(subset=['century']).copy()
df_dated = df_dated[df_dated['word_count'] > 0].copy()
df_dated['century'] = df_dated['century'].astype(int)

def century_label(c: int) -> str:
    """Convert numeric century to a readable label."""
    if c < 0:
        return f"{abs(c)}th c. BCE"
    else:
        return f"{c}th c. CE" if c != 1 else "1st c. CE"

# Nicer labels
ordinal_suffixes = {1: 'st', 2: 'nd', 3: 'rd'}

def century_label(c: int) -> str:
    ac = abs(c)
    suffix = ordinal_suffixes.get(ac, 'th')
    era = 'BCE' if c < 0 else 'CE'
    return f"{ac}{suffix} c. {era}"

df_dated['century_label'] = df_dated['century'].apply(century_label)

# Sort order for centuries (chronological: -8, -7, ... -1, 1, 2, ...)
century_order = sorted(df_dated['century'].unique())
century_labels_ordered = [century_label(c) for c in century_order]

print(f"Total Greek words: {df['word_count'].sum():,}")
print(f"Dated texts with content: {len(df_dated)}")
print(f"Total Greek words with dates: {df_dated['word_count'].sum():,}")
print(f"Century range: {century_labels_ordered[0]} to {century_labels_ordered[-1]}")
# Out:
# Dated texts with content: 1452
# Total Greek words: 30,074,775
# Century range: 8th c. BCE to 12th c. CE

# %% [markdown]
# ## 7. Visualization 1: Textual Data by Century
#
# A stacked bar chart showing the total word count per century,
# split by source repository (Perseus vs. First1KGreek).

# %%
# Aggregate word counts by century and repo
pivot_words = df_dated.pivot_table(
    index='century',
    columns='repo',
    values='word_count',
    aggfunc='sum',
    fill_value=0,
).reindex(century_order, fill_value=0)

# Also count number of texts per century
pivot_texts = df_dated.pivot_table(
    index='century',
    columns='repo',
    values='file',
    aggfunc='count',
    fill_value=0,
).reindex(century_order, fill_value=0)

# ---- Plot: Word count by century (stacked by repo) ----
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Left panel: word counts
colors = {'Perseus': '#3266ad', 'First1KGreek': '#1D9E75'}
x = np.arange(len(century_order))
width = 0.7

bottom = np.zeros(len(century_order))
for repo in ['Perseus', 'First1KGreek']:
    if repo in pivot_words.columns:
        vals = pivot_words[repo].values
        ax1.bar(x, vals, width, bottom=bottom, label=repo,
                color=colors.get(repo, '#888'), alpha=0.85, edgecolor='white', linewidth=0.5)
        bottom += vals

ax1.set_xticks(x)
ax1.set_xticklabels(century_labels_ordered, rotation=45, ha='right', fontsize=9)
ax1.set_ylabel('Total word count')
ax1.set_title('Greek textual data by century', fontsize=13, fontweight='bold', pad=12)
ax1.yaxis.set_major_formatter(ticker.FuncFormatter(lambda v, _: f'{v/1e6:.1f}M' if v >= 1e6 else f'{v/1e3:.0f}K'))
ax1.legend(frameon=False, loc='upper left')

# Annotate total on each bar
totals = pivot_words.sum(axis=1).reindex(century_order, fill_value=0)
for i, total in enumerate(totals):
    if total > 0:
        label = f'{total/1e6:.1f}M' if total >= 1e6 else f'{total/1e3:.0f}K'
        ax1.text(i, total + totals.max() * 0.02, label,
                 ha='center', va='bottom', fontsize=8, color='#555')

# Right panel: number of texts
bottom2 = np.zeros(len(century_order))
for repo in ['Perseus', 'First1KGreek']:
    if repo in pivot_texts.columns:
        vals = pivot_texts[repo].values
        ax2.bar(x, vals, width, bottom=bottom2, label=repo,
                color=colors.get(repo, '#888'), alpha=0.85, edgecolor='white', linewidth=0.5)
        bottom2 += vals

ax2.set_xticks(x)
ax2.set_xticklabels(century_labels_ordered, rotation=45, ha='right', fontsize=9)
ax2.set_ylabel('Number of text files')
ax2.set_title('Number of Greek texts by century', fontsize=13, fontweight='bold', pad=12)
ax2.legend(frameon=False, loc='upper left')

# Annotate totals
totals2 = pivot_texts.sum(axis=1).reindex(century_order, fill_value=0)
for i, total in enumerate(totals2):
    if total > 0:
        ax2.text(i, total + totals2.max() * 0.02, str(int(total)),
                 ha='center', va='bottom', fontsize=8, color='#555')

plt.tight_layout()
plt.savefig('01_textual_data_by_century.png', dpi=150, bbox_inches='tight')
plt.show()
print("Saved: 01_textual_data_by_century.png")
# Out:
# Saved: 01_textual_data_by_century.png

# %% [markdown]
# ## 8. Visualization 2: Prose vs. Poetry by Century
#
# A stacked percentage bar chart showing the proportion of prose, poetry, and mixed
# texts per century (by word count).

# %%
# Aggregate by century and genre
genre_pivot = df_dated.pivot_table(
    index='century',
    columns='genre',
    values='word_count',
    aggfunc='sum',
    fill_value=0,
).reindex(century_order, fill_value=0)

# Ensure all genre columns exist
for g in ['prose', 'poetry', 'mixed']:
    if g not in genre_pivot.columns:
        genre_pivot[g] = 0

# Compute percentages
genre_totals = genre_pivot.sum(axis=1)
genre_pct = genre_pivot.div(genre_totals, axis=0) * 100
genre_pct = genre_pct.fillna(0)

# ---- Plot: percentage stacked bars ----
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 10), gridspec_kw={'height_ratios': [1.2, 1]})

genre_colors = {'poetry': '#7F77DD', 'prose': '#1D9E75', 'mixed': '#BA7517'}
x = np.arange(len(century_order))
width = 0.7

# Top panel: percentage stacked bar
bottom = np.zeros(len(century_order))
for genre in ['poetry', 'prose', 'mixed']:
    vals = genre_pct[genre].values
    bars = ax1.bar(x, vals, width, bottom=bottom, label=genre.capitalize(),
                   color=genre_colors[genre], alpha=0.85, edgecolor='white', linewidth=0.5)
    
    # Add percentage labels on segments >= 10%
    for i, (v, b) in enumerate(zip(vals, bottom)):
        if v >= 10:
            ax1.text(i, b + v/2, f'{v:.0f}%',
                     ha='center', va='center', fontsize=8, color='white', fontweight='bold')
    bottom += vals

ax1.set_xticks(x)
ax1.set_xticklabels(century_labels_ordered, rotation=45, ha='right', fontsize=9)
ax1.set_ylabel('Percentage of word count')
ax1.set_title('Prose vs. poetry by century (% of total words)', fontsize=13, fontweight='bold', pad=12)
ax1.set_ylim(0, 105)
ax1.legend(frameon=False, loc='upper right', ncol=3)
ax1.yaxis.set_major_formatter(ticker.PercentFormatter())

# Bottom panel: absolute word counts by genre
bottom = np.zeros(len(century_order))
for genre in ['poetry', 'prose', 'mixed']:
    vals = genre_pivot[genre].values
    ax2.bar(x, vals, width, bottom=bottom, label=genre.capitalize(),
            color=genre_colors[genre], alpha=0.85, edgecolor='white', linewidth=0.5)
    bottom += vals

ax2.set_xticks(x)
ax2.set_xticklabels(century_labels_ordered, rotation=45, ha='right', fontsize=9)
ax2.set_ylabel('Word count')
ax2.set_title('Prose vs. poetry by century (absolute word count)', fontsize=13, fontweight='bold', pad=12)
ax2.yaxis.set_major_formatter(ticker.FuncFormatter(lambda v, _: f'{v/1e6:.1f}M' if v >= 1e6 else f'{v/1e3:.0f}K'))
ax2.legend(frameon=False, loc='upper left', ncol=3)

plt.tight_layout()
plt.savefig('02_prose_vs_poetry_by_century.png', dpi=150, bbox_inches='tight')
plt.show()
print("Saved: 02_prose_vs_poetry_by_century.png")
# Out:
# Saved: 02_prose_vs_poetry_by_century.png

# %% [markdown]
# ## 9. Summary Table
#
# A compact table showing the data by century with word counts and genre breakdown.

# %%
# Build summary DataFrame
summary_rows = []
for c in century_order:
    mask = df_dated['century'] == c
    sub = df_dated[mask]
    total_words = sub['word_count'].sum()
    n_texts = len(sub)
    poetry_words = sub[sub['genre'] == 'poetry']['word_count'].sum()
    prose_words = sub[sub['genre'] == 'prose']['word_count'].sum()
    mixed_words = sub[sub['genre'] == 'mixed']['word_count'].sum()
    
    summary_rows.append({
        'Century': century_label(c),
        'Period': (
            'Archaic' if c <= -6 else
            'Classical' if c <= -4 else
            'Hellenistic' if c <= -1 else
            'Early Imperial' if c <= 2 else
            'Late Antique'
        ),
        'Texts': n_texts,
        'Total words': f'{total_words:,}',
        'Poetry %': f'{poetry_words/total_words*100:.1f}%' if total_words > 0 else '—',
        'Prose %': f'{prose_words/total_words*100:.1f}%' if total_words > 0 else '—',
        'Mixed %': f'{mixed_words/total_words*100:.1f}%' if total_words > 0 else '—',
        'Top authors': ', '.join(
            sub.groupby('author')['word_count'].sum()
               .nlargest(3).index.tolist()
        ),
    })

df_summary = pd.DataFrame(summary_rows)
df_summary.style.set_properties(**{'text-align': 'left'}).set_table_styles(
    [{'selector': 'th', 'props': [('text-align', 'left')]}]
)
# Out:
# <style type="text/css">
# #T_5f080 th {
#   text-align: left;
# }
# #T_5f080_row0_col0, #T_5f080_row0_col1, #T_5f080_row0_col2, #T_5f080_row0_col3, #T_5f080_row0_col4, #T_5f080_row0_col5, #T_5f080_row0_col6, #T_5f080_row0_col7, #T_5f080_row1_col0, #T_5f080_row1_col1, #T_5f080_row1_col2, #T_5f080_row1_col3, #T_5f080_row1_col4, #T_5f080_row1_col5, #T_5f080_row1_col6, #T_5f080_row1_col7, #T_5f080_row2_col0, #T_5f080_row2_col1, #T_5f080_row2_col2, #T_5f080_row2_col3, #T_5f080_row2_col4, #T_5f080_row2_col5, #T_5f080_row2_col6, #T_5f080_row2_col7, #T_5f080_row3_col0, #T_5f080_row3_col1, #T_5f080_row3_col2, #T_5f080_row3_col3, #T_5f080_row3_col4, #T_5f080_row3_col5, #T_5f080_row3_col6, #T_5f080_row3_col7, #T_5f080_row4_col0, #T_5f080_row4_col1, #T_5f080_row4_col2, #T_5f080_row4_col3, #T_5f080_row4_col4, #T_5f080_row4_col5, #T_5f080_row4_col6, #T_5f080_row4_col7, #T_5f080_row5_col0, #T_5f080_row5_col1, #T_5f080_row5_col2, #T_5f080_row5_col3, #T_5f080_row5_col4, #T_5f080_row5_col5, #T_5f080_row5_col6, #T_5f080_row5_col7, #T_5f080_row6_col0, #T_5f080_row6_col1, #T_5f080_row6_col2, #T_5f080_row6_col3, #T_5f080_row6_col4, #T_5f080_row6_col5, #T_5f080_row6_col6, #T_5f080_row6_col7, #T_5f080_row7_col0, #T_5f080_row7_col1, #T_5f080_row7_col2, #T_5f080_row7_col3, #T_5f080_row7_col4, #T_5f080_row7_col5, #T_5f080_row7_col6, #T_5f080_row7_col7, #T_5f080_row8_col0, #T_5f080_row8_col1, #T_5f080_row8_col2, #T_5f080_row8_col3, #T_5f080_row8_col4, #T_5f080_row8_col5, #T_5f080_row8_col6, #T_5f080_row8_col7, #T_5f080_row9_col0, #T_5f080_row9_col1, #T_5f080_row9_col2, #T_5f080_row9_col3, #T_5f080_row9_col4, #T_5f080_row9_col5, #T_5f080_row9_col6, #T_5f080_row9_col7, #T_5f080_row10_col0, #T_5f080_row10_col1, #T_5f080_row10_col2, #T_5f080_row10_col3, #T_5f080_row10_col4, #T_5f080_row10_col5, #T_5f080_row10_col6, #T_5f080_row10_col7, #T_5f080_row11_col0, #T_5f080_row11_col1, #T_5f080_row11_col2, #T_5f080_row11_col3, #T_5f080_row11_col4, #T_5f080_row11_col5, #T_5f080_row11_col6, #T_5f080_row11_col7, #T_5f080_row12_col0, #T_5f080_row12_col1, #T_5f080_row12_col2, #T_5f080_row12_col3, #T_5f080_row12_col4, #T_5f080_row12_col5, #T_5f080_row12_col6, #T_5f080_row12_col7, #T_5f080_row13_col0, #T_5f080_row13_col1, #T_5f080_row13_col2, #T_5f080_row13_col3, #T_5f080_row13_col4, #T_5f080_row13_col5, #T_5f080_row13_col6, #T_5f080_row13_col7, #T_5f080_row14_col0, #T_5f080_row14_col1, #T_5f080_row14_col2, #T_5f080_row14_col3, #T_5f080_row14_col4, #T_5f080_row14_col5, #T_5f080_row14_col6, #T_5f080_row14_col7, #T_5f080_row15_col0, #T_5f080_row15_col1, #T_5f080_row15_col2, #T_5f080_row15_col3, #T_5f080_row15_col4, #T_5f080_row15_col5, #T_5f080_row15_col6, #T_5f080_row15_col7, #T_5f080_row16_col0, #T_5f080_row16_col1, #T_5f080_row16_col2, #T_5f080_row16_col3, #T_5f080_row16_col4, #T_5f080_row16_col5, #T_5f080_row16_col6, #T_5f080_row16_col7 {
#   text-align: left;
# }
# </style>
# <table id="T_5f080">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f080_level0_col0" class="col_heading level0 col0" >Century</th>
#       <th id="T_5f080_level0_col1" class="col_heading level0 col1" >Period</th>
#       <th id="T_5f080_level0_col2" class="col_heading level0 col2" >Texts</th>
#       <th id="T_5f080_level0_col3" class="col_heading level0 col3" >Total words</th>
#       <th id="T_5f080_level0_col4" class="col_heading level0 col4" >Poetry %</th>
#       <th id="T_5f080_level0_col5" class="col_heading level0 col5" >Prose %</th>
#       <th id="T_5f080_level0_col6" class="col_heading level0 col6" >Mixed %</th>
#       <th id="T_5f080_level0_col7" class="col_heading level0 col7" >Top authors</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f080_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5f080_row0_col0" class="data row0 col0" >8th c. BCE</td>
#       <td id="T_5f080_row0_col1" class="data row0 col1" >Archaic</td>
#       <td id="T_5f080_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_5f080_row0_col3" class="data row0 col3" >199,823</td>
#       <td id="T_5f080_row0_col4" class="data row0 col4" >100.0%</td>
#       <td id="T_5f080_row0_col5" class="data row0 col5" >0.0%</td>
#       <td id="T_5f080_row0_col6" class="data row0 col6" >0.0%</td>
#       <td id="T_5f080_row0_col7" class="data row0 col7" >Homer</td>
#     </tr>
#     <tr>
#       <th id="T_5f080_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5f080_row1_col0" class="data row1 col0" >7th c. BCE</td>
#       <td id="T_5f080_row1_col1" class="data row1 col1" >Archaic</td>
#       <td id="T_5f080_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_5f080_row1_col3" class="data row1 col3" >16,193</td>
#       <td id="T_5f080_row1_col4" class="data row1 col4" >100.0%</td>
#       <td id="T_5f080_row1_col5" class="data row1 col5" >0.0%</td>
#       <td id="T_5f080_row1_col6" class="data row1 col6" >0.0%</td>
#       <td id="T_5f080_row1_col7" class="data row1 col7" >Hesiod</td>
#     </tr>
#     <tr>
#       <th id="T_5f080_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5f080_row2_col0" class="data row2 col0" >6th c. BCE</td>
#       <td id="T_5f080_row2_col1" class="data row2 col1" >Archaic</td>
#       <td id="T_5f080_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_5f080_row2_col3" class="data row2 col3" >3,335</td>
#       <td id="T_5f080_row2_col4" class="data row2 col4" >100.0%</td>
#       <td id="T_5f080_row2_col5" class="data row2 col5" >0.0%</td>
#       <td id="T_5f080_row2_col6" class="data row2 col6" >0.0%</td>
#       <td id="T_5f080_row2_col7" class="data row2 col7" >Batrachomyomachia</td>
#     </tr>
#     <tr>
#       <th id="T_5f080_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5f080_row3_col0" class="data row3 col0" >5th c. BCE</td>
#       <td id="T_5f080_row3_col1" class="data row3 col1" >Classical</td>
#       <td id="T_5f080_row3_col2" class="data row3 col2" >221</td>
#       <td id="T_5f080_row3_col3" class="data row3 col3" >1,828,485</td>
#       <td id="T_5f080_row3_col4" class="data row3 col4" >25.9%</td>
#       <td id="T_5f080_row3_col5" class="data row3 col5" >74.1%</td>
#       <td id="T_5f080_row3_col6" class="data row3 col6" >0.0%</td>
#       <td id="T_5f080_row3_col7" class="data row3 col7" >Hippocrates, Dionysius of Halicarnassus, Herodotus</td>
#     </tr>
#     <tr>
#       <th id="T_5f080_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5f080_row4_col0" class="data row4 col0" >4th c. BCE</td>
#       <td id="T_5f080_row4_col1" class="data row4 col1" >Classical</td>
#       <td id="T_5f080_row4_col2" class="data row4 col2" >384</td>
#       <td id="T_5f080_row4_col3" class="data row4 col3" >3,989,031</td>
#       <td id="T_5f080_row4_col4" class="data row4 col4" >4.1%</td>
#       <td id="T_5f080_row4_col5" class="data row4 col5" >82.7%</td>
#       <td id="T_5f080_row4_col6" class="data row4 col6" >13.2%</td>
#       <td id="T_5f080_row4_col7" class="data row4 col7" >Aristotle, Plutarch, Plato</td>
#     </tr>
#     <tr>
#       <th id="T_5f080_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5f080_row5_col0" class="data row5 col0" >3rd c. BCE</td>
#       <td id="T_5f080_row5_col1" class="data row5 col1" >Hellenistic</td>
#       <td id="T_5f080_row5_col2" class="data row5 col2" >44</td>
#       <td id="T_5f080_row5_col3" class="data row5 col3" >666,869</td>
#       <td id="T_5f080_row5_col4" class="data row5 col4" >11.9%</td>
#       <td id="T_5f080_row5_col5" class="data row5 col5" >71.6%</td>
#       <td id="T_5f080_row5_col6" class="data row5 col6" >16.5%</td>
#       <td id="T_5f080_row5_col7" class="data row5 col7" >Euclid, Chrysippus, Diogenes Laertius</td>
#     </tr>
#     <tr>
#       <th id="T_5f080_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5f080_row6_col0" class="data row6 col0" >2nd c. BCE</td>
#       <td id="T_5f080_row6_col1" class="data row6 col1" >Hellenistic</td>
#       <td id="T_5f080_row6_col2" class="data row6 col2" >7</td>
#       <td id="T_5f080_row6_col3" class="data row6 col3" >86,307</td>
#       <td id="T_5f080

# %% [markdown]
# ## 9b. Poetry Lines Embedded in Prose Texts
#
# Many prose works quote or embed verse lines (marked with `<l>` in TEI XML).
# This section re-parses prose-classified texts to count those embedded verse lines,
# revealing how much poetic material is woven into the prose tradition.
# We report per-work counts and then aggregate summaries by century and author.

# %%
# ── Count <l> (verse-line) elements inside prose-classified texts ──

def count_verse_lines_in_file(filepath):
    """Parse a TEI XML file and return the number of <l> elements in the body."""
    try:
        tree = etree.parse(filepath)
    except etree.XMLSyntaxError:
        return 0
    root = tree.getroot()
    total = 0
    for ns_prefix in ['{http://www.tei-c.org/ns/1.0}', '']:
        total = len(root.findall(f'.//{ns_prefix}l'))
        if total > 0:
            break
    return total


def resolve_filepath(row):
    """Reconstruct the full path for a file from its basename and repo label."""
    if row['repo'] == 'Perseus':
        base = REPOS['perseus']['dir']
    else:
        base = REPOS['first1k']['dir']
    matches = glob.glob(os.path.join(base, 'data', '**', row['file']), recursive=True)
    return matches[0] if matches else None


# Subset: prose texts only
df_prose = df_dated[df_dated['genre'] == 'prose'].copy()
print(f"Prose texts to scan: {len(df_prose)}")

# Resolve full paths and count verse lines
df_prose['full_path'] = df_prose.apply(resolve_filepath, axis=1)
df_prose = df_prose.dropna(subset=['full_path'])
df_prose['verse_lines'] = df_prose['full_path'].apply(count_verse_lines_in_file)

# ── Per-work table (only works that actually contain verse lines) ──
df_with_verse = df_prose[df_prose['verse_lines'] > 0].copy()
df_with_verse = df_with_verse.sort_values('verse_lines', ascending=False)

print(f"\nProse texts containing embedded verse lines: "
      f"{len(df_with_verse)} of {len(df_prose)} "
      f"({len(df_with_verse)/len(df_prose)*100:.1f}%)")
print(f"Total embedded verse lines across all prose texts: "
      f"{df_with_verse['verse_lines'].sum():,}\n")

# Display the per-work table
per_work = df_with_verse[['author', 'file', 'century_label', 'word_count',
                          'verse_lines', 'repo']].copy()
per_work.columns = ['Author', 'File', 'Century', 'Word count',
                     'Embedded verse lines', 'Repo']
per_work = per_work.reset_index(drop=True)
print("── Per-work counts (prose texts with embedded verse lines) ──")
display(per_work.style.set_properties(**{'text-align': 'left'})
        .set_table_styles([{'selector': 'th',
                            'props': [('text-align', 'left')]}])
        .format({'Word count': '{:,}'}))

# ── Summary by century ──
century_summary = (
    df_with_verse.groupby('century')
    .agg(
        prose_texts_with_verse=('file', 'count'),
        total_verse_lines=('verse_lines', 'sum'),
        mean_verse_lines=('verse_lines', 'mean'),
        max_verse_lines=('verse_lines', 'max'),
    )
    .reindex(century_order, fill_value=0)
)

# Add total prose texts per century for context
prose_per_century = df_prose.groupby('century')['file'].count()
century_summary['total_prose_texts'] = prose_per_century.reindex(century_order, fill_value=0)
century_summary['pct_with_verse'] = (
    century_summary['prose_texts_with_verse']
    / century_summary['total_prose_texts'].replace(0, float('nan')) * 100
)
century_summary.index = [century_label(c) for c in century_summary.index]
century_summary = century_summary[century_summary['total_prose_texts'] > 0]

print("\n── Summary by century ──")
display(century_summary.style.format({
    'total_verse_lines': '{:,.0f}',
    'mean_verse_lines': '{:.1f}',
    'max_verse_lines': '{:,.0f}',
    'pct_with_verse': '{:.1f}%',
}).set_properties(**{'text-align': 'left'}))

# ── Summary by author (top 20) ──
author_summary = (
    df_with_verse.groupby('author')
    .agg(
        prose_works=('file', 'count'),
        total_verse_lines=('verse_lines', 'sum'),
        mean_per_work=('verse_lines', 'mean'),
        total_words=('word_count', 'sum'),
    )
    .sort_values('total_verse_lines', ascending=False)
)
author_summary['lines_per_10k_words'] = (
    author_summary['total_verse_lines']
    / author_summary['total_words'] * 10_000
)

print("\n── Top 20 authors by embedded verse lines in prose ──")
display(author_summary.head(20).style.format({
    'total_verse_lines': '{:,}',
    'mean_per_work': '{:.1f}',
    'total_words': '{:,}',
    'lines_per_10k_words': '{:.1f}',
}).set_properties(**{'text-align': 'left'}))

# ── Quick bar chart ──
top_authors = author_summary.head(15)
fig, ax = plt.subplots(figsize=(12, 6))
ax.barh(top_authors.index[::-1], top_authors['total_verse_lines'].values[::-1],
        color='#7F77DD', alpha=0.85, edgecolor='white', linewidth=0.5)
ax.set_xlabel('Embedded verse lines in prose works')
ax.set_title('Top 15 prose authors by number of embedded verse lines',
             fontsize=13, fontweight='bold', pad=12)
for i, (v, name) in enumerate(zip(top_authors['total_verse_lines'].values[::-1],
                                   top_authors.index[::-1])):
    ax.text(v + top_authors['total_verse_lines'].max() * 0.01, i,
            f'{v:,}', va='center', fontsize=9, color='#555')
plt.tight_layout()
plt.savefig('03_verse_lines_in_prose.png', dpi=150, bbox_inches='tight')
plt.show()
print("Saved: 03_verse_lines_in_prose.png")
# Out:
# Prose texts to scan: 1198
#
# Prose texts containing embedded verse lines: 321 of 1198 (26.8%)
# Total embedded verse lines across all prose texts: 6,456
#
# ── Per-work counts (prose texts with embedded verse lines) ──
# <style type="text/css">
# #T_f4a0c th {
#   text-align: left;
# }
# #T_f4a0c_row0_col0, #T_f4a0c_row0_col1, #T_f4a0c_row0_col2, #T_f4a0c_row0_col3, #T_f4a0c_row0_col4, #T_f4a0c_row0_col5, #T_f4a0c_row1_col0, #T_f4a0c_row1_col1, #T_f4a0c_row1_col2, #T_f4a0c_row1_col3, #T_f4a0c_row1_col4, #T_f4a0c_row1_col5, #T_f4a0c_row2_col0, #T_f4a0c_row2_col1, #T_f4a0c_row2_col2, #T_f4a0c_row2_col3, #T_f4a0c_row2_col4, #T_f4a0c_row2_col5, #T_f4a0c_row3_col0, #T_f4a0c_row3_col1, #T_f4a0c_row3_col2, #T_f4a0c_row3_col3, #T_f4a0c_row3_col4, #T_f4a0c_row3_col5, #T_f4a0c_row4_col0, #T_f4a0c_row4_col1, #T_f4a0c_row4_col2, #T_f4a0c_row4_col3, #T_f4a0c_row4_col4, #T_f4a0c_row4_col5, #T_f4a0c_row5_col0, #T_f4a0c_row5_col1, #T_f4a0c_row5_col2, #T_f4a0c_row5_col3, #T_f4a0c_row5_col4, #T_f4a0c_row5_col5, #T_f4a0c_row6_col0, #T_f4a0c_row6_col1, #T_f4a0c_row6_col2, #T_f4a0c_row6_col3, #T_f4a0c_row6_col4, #T_f4a0c_row6_col5, #T_f4a0c_row7_col0, #T_f4a0c_row7_col1, #T_f4a0c_row7_col2, #T_f4a0c_row7_col3, #T_f4a0c_row7_col4, #T_f4a0c_row7_col5, #T_f4a0c_row8_col0, #T_f4a0c_row8_col1, #T_f4a0c_row8_col2, #T_f4a0c_row8_col3, #T_f4a0c_row8_col4, #T_f4a0c_row8_col5, #T_f4a0c_row9_col0, #T_f4a0c_row9_col1, #T_f4a0c_row9_col2, #T_f4a0c_row9_col3, #T_f4a0c_row9_col4, #T_f4a0c_row9_col5, #T_f4a0c_row10_col0, #T_f4a0c_row10_col1, #T_f4a0c_row10_col2, #T_f4a0c_row10_col3, #T_f4a0c_row10_col4, #T_f4a0c_row10_col5, #T_f4a0c_row11_col0, #T_f4a0c_row11_col1, #T_f4a0c_row11_col2, #T_f4a0c_row11_col3, #T_f4a0c_row11_col4, #T_f4a0c_row11_col5, #T_f4a0c_row12_col0, #T_f4a0c_row12_col1, #T_f4a0c_row12_col2, #T_f4a0c_row12_col3, #T_f4a0c_row12_col4, #T_f4a0c_row12_col5, #T_f4a0c_row13_col0, #T_f4a0c_row13_col1, #T_f4a0c_row13_col2, #T_f4a0c_row13_col3, #T_f4a0c_row13_col4, #T_f4a0c_row13_col5, #T_f4a0c_row14_col0, #T_f4a0c_row14_col1, #T_f4a0c_row14_col2, #T_f4a0c_row14_col3, #T_f4a0c_row14_col4, #T_f4a0c_row14_col5, #T_f4a0c_row15_col0, #T_f4a0c_row15_col1, #T_f4a0c_row15_col2, #T_f4a0c_row15_col3, #T_f4a0c_row15_col4, #T_f4a0c_row15_col5, #T_f4a0c_row16_col0, #T_f4a0c_row16_col1, #T_f4a0c_row16_col2, #T_f4a0c_row16_col3, #T_f4a0c_row16_col4, #T_f4a0c_row16_col5, #T_f4a0c_row17_col0, #T_f4a0c_row17_col1, #T_f4a0c_row17_col2, #T_f4a0c_row17_col3, #T_f4a0c_row17_col4, #T_f4a0c_row17_col5, #T_f4a0c_row18_col0, #T_f4a0c_row18_col1, #T_f4a0c_row18_col2, #T_f4a0c_row18_col3, #T_f4a0c_row18_col4, #T_f4a0c_row18_col5, #T_f4a0c_row19_col0, #T_f4a0c_row19_col1, #T_f4a0c_row19_col2, #T_f4a0c_row19_col3, #T_f4a0c_row19_col4, #T_f4a0c_row19_col5, #T_f4a0c_row20_col0, #T_f4a0c_row20_col1, #T_f4a0c_row20_col2, #T_f4a0c_row20_col3, #T_f4a0c_row20_col4, #T_f4a0c_row20_col5, #T_f4a0c_row21_col0, #T_f4a0c_row21_col1, #T_f4a0c_row21_col2, #T_f4a0c_row21_col3, #T_f4a0c_row21_col4, #T_f4a0c_row21_col5, #T_f4a0c_row22_col0, #T_f4a0c_row22_col1, #T_f4a0c_row22_col2, #T_f4a0c_row22_col3, #T_f4a0c_row22_col4, #T_f4a0c_row22_col5, #T_f4a0c_row23_col0, #T_f4a0c_row23_col1, #T_f4a0c_row23_col2, #T_f4a0c_row23_col3, #T_f4a0c_row23_col4, #T_f4a0c_row23_col5, #T_f4a0c_row24_col0, #T_f4a0c_row24_col1, #T_f4a0c_row24_col2, #T_f4a0c_row24_col3, #T_f4a0c_row24_col4, #T_f4a0c_row24_col5, #T_f4a0c_row25_col0, #T_f4a0c_row25_col1, #T_f4a0c_row25_col2, #T_f4a0c_row25_col3, #T_f4a0c_row25_col4, #T_f4a0c_row25_col5, #T_f4a0c_row26_col0, #T_f4a0c_row26_col1, #T_f4a0c_row26_col2, #T_f4a0c_row26_col3, #T_f4a0c_row26_col4, #T_f4a0c_row26_col5, #T_f4a0c_row27_col0, #T_f4a0c_row27_col1, #T_f4a0c_row27_col2, #T_f4a0c_row27_col3, #T_f4a0c_row27_col4, #T_f4a0c_row27_col5, #T_f4a0c_row28_col0, #T_f4a0c_row28_col1, #T_f4a0c_row28_col2, #T_f4a0c_row28_col3, #T_f4a0c_row28_col4, #T_f4a0c_row28_col5, #T_f4a0c_row29_col0, #T_f4a0c_row29_col1, #T_f4a0c_row29_col2, #T_f4a0c_row29_col3, #T_f4a0c_row29_col4, #T_f4a0c_row29_col5, #T_f4a0c_row30_col0, #T_f4a0c_row30_col1, #T_f4a0c_row30_col2, #T_f4a0c_row30_col3, #T_f4a0c_row30_col4, #T_f4a0c_row30_col5, #T_f4a0c_row31_col0, #T_f4a0c_row31_col1, #T_f4a0c_row31_col2, #T_f4a0c_row31_col3, #T_f4a0c_row31_col4, #T_f4a0c_row31_col5, #T_f4a0c_row32_col0, #T_f4a0 ...
# ── Summary by century ──
# <style type="text/css">
# #T_e4b7e_row0_col0, #T_e4b7e_row0_col1, #T_e4b7e_row0_col2, #T_e4b7e_row0_col3, #T_e4b7e_row0_col4, #T_e4b7e_row0_col5, #T_e4b7e_row1_col0, #T_e4b7e_row1_col1, #T_e4b7e_row1_col2, #T_e4b7e_row1_col3, #T_e4b7e_row1_col4, #T_e4b7e_row1_col5, #T_e4b7e_row2_col0, #T_e4b7e_row2_col1, #T_e4b7e_row2_col2, #T_e4b7e_row2_col3, #T_e4b7e_row2_col4, #T_e4b7e_row2_col5, #T_e4b7e_row3_col0, #T_e4b7e_row3_col1, #T_e4b7e_row3_col2, #T_e4b7e_row3_col3, #T_e4b7e_row3_col4, #T_e4b7e_row3_col5, #T_e4b7e_row4_col0, #T_e4b7e_row4_col1, #T_e4b7e_row4_col2, #T_e4b7e_row4_col3, #T_e4b7e_row4_col4, #T_e4b7e_row4_col5, #T_e4b7e_row5_col0, #T_e4b7e_row5_col1, #T_e4b7e_row5_col2, #T_e4b7e_row5_col3, #T_e4b7e_row5_col4, #T_e4b7e_row5_col5, #T_e4b7e_row6_col0, #T_e4b7e_row6_col1, #T_e4b7e_row6_col2, #T_e4b7e_row6_col3, #T_e4b7e_row6_col4, #T_e4b7e_row6_col5, #T_e4b7e_row7_col0, #T_e4b7e_row7_col1, #T_e4b7e_row7_col2, #T_e4b7e_row7_col3, #T_e4b7e_row7_col4, #T_e4b7e_row7_col5, #T_e4b7e_row8_col0, #T_e4b7e_row8_col1, #T_e4b7e_row8_col2, #T_e4b7e_row8_col3, #T_e4b7e_row8_col4, #T_e4b7e_row8_col5, #T_e4b7e_row9_col0, #T_e4b7e_row9_col1, #T_e4b7e_row9_col2, #T_e4b7e_row9_col3, #T_e4b7e_row9_col4, #T_e4b7e_row9_col5, #T_e4b7e_row10_col0, #T_e4b7e_row10_col1, #T_e4b7e_row10_col2, #T_e4b7e_row10_col3, #T_e4b7e_row10_col4, #T_e4b7e_row10_col5, #T_e4b7e_row11_col0, #T_e4b7e_row11_col1, #T_e4b7e_row11_col2, #T_e4b7e_row11_col3, #T_e4b7e_row11_col4, #T_e4b7e_row11_col5, #T_e4b7e_row12_col0, #T_e4b7e_row12_col1, #T_e4b7e_row12_col2, #T_e4b7e_row12_col3, #T_e4b7e_row12_col4, #T_e4b7e_row12_col5, #T_e4b7e_row13_col0, #T_e4b7e_row13_col1, #T_e4b7e_row13_col2, #T_e4b7e_row13_col3, #T_e4b7e_row13_col4, #T_e4b7e_row13_col5 {
#   text-align: left;
# }
# </style>
# <table id="T_e4b7e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4b7e_level0_col0" class="col_heading level0 col0" >prose_texts_with_verse</th>
#       <th id="T_e4b7e_level0_col1" class="col_heading level0 col1" >total_verse_lines</th>
#       <th id="T_e4b7e_level0_col2" class="col_heading level0 col2" >mean_verse_lines</th>
#       <th id="T_e4b7e_level0_col3" class="col_heading level0 col3" >max_verse_lines</th>
#       <th id="T_e4b7e_level0_col4" class="col_heading level0 col4" >total_prose_texts</th>
#       <th id="T_e4b7e_level0_col5" class="col_heading level0 col5" >pct_with_verse</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4b7e_level0_row0" class="row_heading level0 row0" >5th c. BCE</th>
#       <td id="T_e4b7e_row0_col0" class="data row0 col0" >6</td>
#       <td id="T_e4b7e_row0_col1" class="data row0 col1" >254</td>
#       <td id="T_e4b7e_row0_col2" class="data row0 col2" >42.3</td>
#       <td id="T_e4b7e_row0_col3" class="data row0 col3" >151</td>
#       <td id="T_e4b7e_row0_col4" class="data row0 col4" >130</td>
#       <td id="T_e4b7e_row0_col5" class="data row0 col5" >4.6%</td>
#     </tr>
#     <tr>
#       <th id="T_e4b7e_level0_row1" class="row_heading level0 row1" >4th c. BCE</th>
#       <td id="T_e4b7e_row1_col0" class="data row1 col0" >105</td>
#       <td id="T_e4b7e_row1_col1" class="data row1 col1" >1,216</td>
#       <td id="T_e4b7e_row1_col2" class="data row1 col2" >11.6</td>
#       <td id="T_e4b7e_row1_col3" class="data row1 col3" >147</td>
#       <td id="T_e4b7e_row1_col4" class="data row1 col4" >318</td>
#       <td id="T_e4b7e_row1_col5" class="data row1 col5" >33.0%</td>
#     </tr>
#     <tr>
#       <th id="T_e4b7e_level0_row2" class="row_heading level0 row2" >3rd c. BCE</th>
#       <td id="T_e4b7e_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_e4b7e_row2_col1" class="data row2 col1" >23</td>
#       <td id="T_e4b7e_row2_col2" class="data row2 col2" >7.7</td>
#       <td id="T_e4b7e_row2_col3" class="data row2 col3" >19</td>
#       <td id="T_e4b7e_row2_col4" class="data row2 col4" >25</td>
#       <td id="T_e4b7e_row2_col5" class="data row2 col5" >12.0%</td>
#     </tr>
#     <tr>
#       <th id="T_e4b7e_level0_row3" class="row_heading level0 row3" >2nd c. BCE</th>
#       <td id="T_e4b7e_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_e4b7e_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_e4b7e_row3_col2" class="data row3 col2" >0.0</td>
#       <td id="T_e4b7e_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_e4b7e_row3_col4" class="data row3 col4" >7</td>
#       <td id="T_e4b7e_row3_col5" class="data row3 col5" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_e4b7e_level0_row4" class="row_heading level0 row4" >1st c. BCE</th>
#       <td id="T_e4b7e_row4_col0" class="data row4 col0" >24</td>
#       <td id="T_e4b7e_row4_col1" class="data row4 col1" >200</td>
#       <td id="T_e4b7e_row4_col2" class="data row4 col2" >8.3</td>
#       <td id="T_e4b7e_row4_col3" class="data row4 col3" >38</td>
#       <td id="T_e4b7e_row4_col4" class="data row4 col4" >114</td>
#       <td id="T_e4b7e_row4_col5" class="data row4 col5" >21.1%</td>
#     </tr>
#     <tr>
#       <th id="T_e4b7e_level0_row5" class="row_heading level0 row5" >1st c. CE</th>
#       <td id="T_e4b7e_row5_col0" class="data row5 col0" >64</td>
#       <td id="T_e4b7e_row5_col1" class="data row5 col1" >1,693</td>
#       <td id="T_e4b7e_row5_col2" class="data row5 col2" >26.5</td>
#       <td id="T_e4b7e_row5_col3" class="data row5 col3" >282</td>
#       <td id="T_e4b7e_row5_col4" class="data row5 col4" >184</td>
#       <td id="T_e4b7e_row5_col5" class="data row5 col5" >34.8%</td>
#     </tr>
#     <tr>
#       <th id="T_e4b7e_level0_row6" class="row_heading level0 row6" >2nd c. CE</th>
#       <td id="T_e4b7e_row6_col0" class="data row6 col0" >31</td>
#       <td id="T_e4b7e_row6_col1" class="data row6 col1" >1,285</td>
#       <td id="T_e4b7e_row6_col2" class="data row6 col2" >41.5</td>
#       <td id="T_e4b7e_row6_col3" class="data row6 col3" >451</td>
#       <td id="T_e4b7e_row6_col4" class="data row6 col4" >127</td>
#       <td id="T_e4b7e_row6_col5" class="data row6 col5" >24.4%</td>
#     </tr>
#     <tr>
#       <th id="T_e4b7e_level0_row7" class="row_heading level0 row7" >3rd c. CE</th>
#       <td id="T_e4b7e_row7_col0" class="data row7 col0" >12</td>
#       <td id="T_e4b7e_row7_col1" class="data row7 col1" >433</td>
#       <td id="T_e4b7e_row7_col2" class="data row7 col2" >36.1</td>
#       <td id="T_e4b7e_row7_col3" class="data row7 col3" >211</td>
#       <td id="T_e4b7e_row7_col4" class="data row7 col4" >57</td>
#       <td id="T_e4b7e_row7_col5" class="data row7 col5" >21.1%</td>
#     </tr>
#     <tr>
#       <th id="T_e4b7e_level0_row8" class="row_heading level0 row8" >4th c. CE</th>
#       <td id="T_e4b7e_row8_col0" class="data row8 col0" >40</td>
#       <td id="T_e4b7e_row8_col1" class="data row8 col1" >271</td>
#       <td id="T_e4b7e_row8_col2" class="data row8 col2" >6.8</td>
#       <td id="T_e4b7e_row8_col3" class="data row8 col3" >33</td>
#       <td id="T_e4b7e_row8_col4" class="data row8 col4" >150</td>
#       <td id="T_e4b7e_row8_col5" class="data row8 col5" >26.7%</td>
#     </tr>
#     <tr>
#       <th id="T_e4b7e_level0_row9" class="row_heading level0 row9" >5th c. CE</th>
#       <td id="T_e4b7e_row9_col0" class="data row9 col0" >13</td>
#       <td id="T_e4b7e_row9_col1" class="data row9 col1" >302</td>
#       <td id="T_e4b7e_row9_col2" class="data row9 col2" >23.2</td>
#       <td id="T_e4b7e_row9_col3" class="data row9 col3" >99</td>
#       <td id="T_e4b7e_row9_col4" class="data row9 col4" >23</td>
#       <td id="T_e4b7e_row9_col5" class="data row9 col5" >56.5%</td>
#     </tr>
#     <tr>
#       <th id="T_e4b7e_level0_row10" class="row_heading level0 row10" >6th c. CE</th>
#       <td id="T_e4b7e_row10_col0" class="data row10 col0" >8</td>
#       <td id="T_e4b7e_row10_col1" class="data row10 col1" >515</td>
#       <td id="T_e4b7e_row10_col2" class="data row10 col2" >64.4</td>
#       <td id="T_e4b7e_row10_col3" class="data row10 col3" >360</td>
#       <td id="T_e4b7e_row10_col4" class="data row10 col4" >10</td>
#       <td id="T_e4b7e_row10_col5" class="data row10 col5" >80.0%</td>
#     </tr>
#     <tr>
#       <th id="T_e4b7e_level0_row11" class="row_heading level0 row11" >
# ── Top 20 authors by embedded verse lines in prose ──
# <style type="text/css">
# #T_2add8_row0_col0, #T_2add8_row0_col1, #T_2add8_row0_col2, #T_2add8_row0_col3, #T_2add8_row0_col4, #T_2add8_row1_col0, #T_2add8_row1_col1, #T_2add8_row1_col2, #T_2add8_row1_col3, #T_2add8_row1_col4, #T_2add8_row2_col0, #T_2add8_row2_col1, #T_2add8_row2_col2, #T_2add8_row2_col3, #T_2add8_row2_col4, #T_2add8_row3_col0, #T_2add8_row3_col1, #T_2add8_row3_col2, #T_2add8_row3_col3, #T_2add8_row3_col4, #T_2add8_row4_col0, #T_2add8_row4_col1, #T_2add8_row4_col2, #T_2add8_row4_col3, #T_2add8_row4_col4, #T_2add8_row5_col0, #T_2add8_row5_col1, #T_2add8_row5_col2, #T_2add8_row5_col3, #T_2add8_row5_col4, #T_2add8_row6_col0, #T_2add8_row6_col1, #T_2add8_row6_col2, #T_2add8_row6_col3, #T_2add8_row6_col4, #T_2add8_row7_col0, #T_2add8_row7_col1, #T_2add8_row7_col2, #T_2add8_row7_col3, #T_2add8_row7_col4, #T_2add8_row8_col0, #T_2add8_row8_col1, #T_2add8_row8_col2, #T_2add8_row8_col3, #T_2add8_row8_col4, #T_2add8_row9_col0, #T_2add8_row9_col1, #T_2add8_row9_col2, #T_2add8_row9_col3, #T_2add8_row9_col4, #T_2add8_row10_col0, #T_2add8_row10_col1, #T_2add8_row10_col2, #T_2add8_row10_col3, #T_2add8_row10_col4, #T_2add8_row11_col0, #T_2add8_row11_col1, #T_2add8_row11_col2, #T_2add8_row11_col3, #T_2add8_row11_col4, #T_2add8_row12_col0, #T_2add8_row12_col1, #T_2add8_row12_col2, #T_2add8_row12_col3, #T_2add8_row12_col4, #T_2add8_row13_col0, #T_2add8_row13_col1, #T_2add8_row13_col2, #T_2add8_row13_col3, #T_2add8_row13_col4, #T_2add8_row14_col0, #T_2add8_row14_col1, #T_2add8_row14_col2, #T_2add8_row14_col3, #T_2add8_row14_col4, #T_2add8_row15_col0, #T_2add8_row15_col1, #T_2add8_row15_col2, #T_2add8_row15_col3, #T_2add8_row15_col4, #T_2add8_row16_col0, #T_2add8_row16_col1, #T_2add8_row16_col2, #T_2add8_row16_col3, #T_2add8_row16_col4, #T_2add8_row17_col0, #T_2add8_row17_col1, #T_2add8_row17_col2, #T_2add8_row17_col3, #T_2add8_row17_col4, #T_2add8_row18_col0, #T_2add8_row18_col1, #T_2add8_row18_col2, #T_2add8_row18_col3, #T_2add8_row18_col4, #T_2add8_row19_col0, #T_2add8_row19_col1, #T_2add8_row19_col2, #T_2add8_row19_col3, #T_2add8_row19_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_2add8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2add8_level0_col0" class="col_heading level0 col0" >prose_works</th>
#       <th id="T_2add8_level0_col1" class="col_heading level0 col1" >total_verse_lines</th>
#       <th id="T_2add8_level0_col2" class="col_heading level0 col2" >mean_per_work</th>
#       <th id="T_2add8_level0_col3" class="col_heading level0 col3" >total_words</th>
#       <th id="T_2add8_level0_col4" class="col_heading level0 col4" >lines_per_10k_words</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >author</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2add8_level0_row0" class="row_heading level0 row0" >Septuaginta</th>
#       <td id="T_2add8_row0_col0" class="data row0 col0" >20</td>
#       <td id="T_2add8_row0_col1" class="data row0 col1" >815</td>
#       <td id="T_2add8_row0_col2" class="data row0 col2" >40.8</td>
#       <td id="T_2add8_row0_col3" class="data row0 col3" >504,789</td>
#       <td id="T_2add8_row0_col4" class="data row0 col4" >16.1</td>
#     </tr>
#     <tr>
#       <th id="T_2add8_level0_row1" class="row_heading level0 row1" >Sextus Empiricus</th>
#       <td id="T_2add8_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_2add8_row1_col1" class="data row1 col1" >546</td>
#       <td id="T_2add8_row1_col2" class="data row1 col2" >273.0</td>
#       <td id="T_2add8_row1_col3" class="data row1 col3" >221,578</td>
#       <td id="T_2add8_row1_col4" class="data row1 col4" >24.6</td>
#     </tr>
#     <tr>
#       <th id="T_2add8_level0_row2" class="row_heading level0 row2" >Plutarch</th>
#       <td id="T_2add8_row2_col0" class="data row2 col0" >60</td>
#       <td id="T_2add8_row2_col1" class="data row2 col1" >503</td>
#       <td id="T_2add8_row2_col2" class="data row2 col2" >8.4</td>
#       <td id="T_2add8_row2_col3" class="data row2 col3" >517,257</td>
#       <td id="T_2add8_row2_col4" class="data row2 col4" >9.7</td>
#     </tr>
#     <tr>
#       <th id="T_2add8_level0_row3" class="row_heading level0 row3" >Simplicius</th>
#       <td id="T_2add8_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_2add8_row3_col1" class="data row3 col1" >490</td>
#       <td id="T_2add8_row3_col2" class="data row3 col2" >122.5</td>
#       <td id="T_2add8_row3_col3" class="data row3 col3" >1,140,771</td>
#       <td id="T_2add8_row3_col4" class="data row3 col4" >4.3</td>
#     </tr>
#     <tr>
#       <th id="T_2add8_level0_row4" class="row_heading level0 row4" >Pausanias</th>
#       <td id="T_2add8_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_2add8_row4_col1" class="data row4 col1" >451</td>
#       <td id="T_2add8_row4_col2" class="data row4 col2" >451.0</td>
#       <td id="T_2add8_row4_col3" class="data row4 col3" >217,618</td>
#       <td id="T_2add8_row4_col4" class="data row4 col4" >20.7</td>
#     </tr>
#     <tr>
#       <th id="T_2add8_level0_row5" class="row_heading level0 row5" >Unknown</th>
#       <td id="T_2add8_row5_col0" class="data row5 col0" >13</td>
#       <td id="T_2add8_row5_col1" class="data row5 col1" >404</td>
#       <td id="T_2add8_row5_col2" class="data row5 col2" >31.1</td>
#       <td id="T_2add8_row5_col3" class="data row5 col3" >119,158</td>
#       <td id="T_2add8_row5_col4" class="data row5 col4" >33.9</td>
#     </tr>
#     <tr>
#       <th id="T_2add8_level0_row6" class="row_heading level0 row6" >Aristotle</th>
#       <td id="T_2add8_row6_col0" class="data row6 col0" >15</td>
#       <td id="T_2add8_row6_col1" class="data row6 col1" >396</td>
#       <td id="T_2add8_row6_col2" class="data row6 col2" >26.4</td>
#       <td id="T_2add8_row6_col3" class="data row6 col3" >474,822</td>
#       <td id="T_2add8_row6_col4" class="data row6 col4" >8.3</td>
#     </tr>
#     <tr>
#       <th id="T_2add8_level0_row7" class="row_heading level0 row7" >Aelius Herodianus</th>
#       <td id="T_2add8_row7_col0" class="data row7 col0" >1</td>
#       <td id="T_2add8_row7_col1" class="data row7 col1" >282</td>
#       <td id="T_2add8_row7_col2" class="data row7 col2" >282.0</td>
#       <td id="T_2add8_row7_col3" class="data row7 col3" >136,723</td>
#       <td id="T_2add8_row7_col4" class="data row7 col4" >20.6</td>
#     </tr>
#     <tr>
#       <th id="T_2add8_level0_row8" class="row_heading level0 row8" >Hippolytus</th>
#       <td id="T_2add8_row8_col0" class="data row8 col0" >1</td>
#       <td id="T_2add8_row8_col1" class="data row8 col1" >211</td>
#       <td id="T_2add8_row8_col2" class="data row8 col2" >211.0</td>
#       <td id="T_2add8_row8_col3" class="data row8 col3" >90,083</td>
#       <td id="T_2add8_row8_col4" class="data row8 col4" >23.4</td>
#     </tr>
#     <tr>
#       <th id="T_2add8_level0_row9" class="row_heading level0 row9" >Libanius</th>
#       <td id="T_2add8_row9_col0" class="data row9 col0" >30</td>
#       <td id="T_2add8_row9_col1" class="data row9 col1" >201</td>
#       <td id="T_2add8_row9_col2" class="data row9 col2" >6.7</td>
#       <td id="T_2add8_row9_col3" class="data row9 col3" >366,930</td>
#       <td id="T_2add8_row9_col4" class="data row9 col4" >5.5</td>
#     </tr>
#     <tr>
#       <th id="T_2add8_level0_row10" class="row_heading level0 row10" >Plato</th>
#       <td id="T_2add8_row10_col0" class="data row10 col0" >22</td>
#       <td id="T_2add8_row10_col1" class="data row10 col1" >194</td>
#       <td id="T_2add8_row10_col2" class="data row10 col2" >8.8</td>
#       <td id="T_2add8_row10_col3" class="data row10 col3" >343,080</td>
#       <td id="T_2add8_row10_col4" class="data row10 col4" >5.7</td>
#     </tr>
#     <tr>
#       <th id="T_2add8_level0_row11" class="row_heading level0 row11" >Eusebius</th>
#       <td id="T_2add8_row11_col0" class="data row11 col0" >4</td>
#       <td id="T_2add8_row11_col1" class="data row11 col1" >170</td>
#       <td
# Saved: 03_verse_lines_in_prose.png

# %% [markdown]
# ## 10. Undated Texts Report
#
# Show which TLG codes weren't in our mapping so you can extend it.

# %%
undated = df[df['century'].isna() & (df['word_count'] > 0)].copy()

if len(undated) > 0:
    undated_summary = (
        undated.groupby(['tlg_code', 'author'])
        .agg(files=('file', 'count'), total_words=('word_count', 'sum'))
        .sort_values('total_words', ascending=False)
        .head(30)
    )
    print(f"Top 30 undated TLG codes (by word count) — add these to TLG_CENTURY_CLEAN:")
    print()
    for (tlg, author), row in undated_summary.iterrows():
        print(f"    '{tlg}': ??,   # {author} ({row['files']} files, {row['total_words']:,} words)")
else:
    print("All texts with content have century assignments!")
# Out:
# Top 30 undated TLG codes (by word count) — add these to TLG_CENTURY_CLEAN:
#
#     '0638': ??,   # Philostratus the Athenian (5 files, 143,588 words)
#     '7000': ??,   # Unknown (5 files, 136,416 words)
#     '2371': ??,   # Chronicon Paschale (1 files, 132,363 words)
#     '0559': ??,   # Hero of Alexandria (12 files, 129,956 words)
#     '2045': ??,   # Nonnus of Panopolis (1 files, 127,720 words)
#     '2003': ??,   # Julian the Emperor (14 files, 123,236 words)
#     '1271': ??,   # Clemens Romanus (7 files, 120,928 words)
#     '0074': ??,   # Arrian (7 files, 112,999 words)
#     '2048': ??,   # Sozomenus, Salaminius Hermias (1 files, 112,976 words)
#     '2034': ??,   # Porphyry (2 files, 111,345 words)
#     '1764': ??,   # Vettius Valens (1 files, 110,777 words)
#     '0552': ??,   # Archimède (12 files, 106,859 words)
#     '4020': ??,   # Elias Neoplatonicus (2 files, 104,283 words)
#     '2057': ??,   # Socrates, Scholasticus (1 files, 101,826 words)
#     '0592': ??,   # Hermogenes (5 files, 100,776 words)
#     '4033': ??,   # Anonymi In Aristotelis Ethica Nicomachea (1 files, 100,139 words)
#     '4026': ??,   # Anonymi in Aristotelis Artem Rhetoricam (3 files, 98,702 words)
#     '0563': ??,   # Maximus of Tyre (1 files, 97,637 words)
#     '2034': ??,   # Porphyrius (6 files, 91,806 words)
#     '0530': ??,   # Pseudo-Galen (6 files, 91,320 words)
#     '4034': ??,   # Michael of Ephesus (3 files, 90,953 words)
#     '4021': ??,   # David the Invincible (2 files, 90,090 words)
#     '0616': ??,   # Polyaenus (2 files, 89,873 words)
#     '2035': ??,   # Athanasius (4 files, 87,731 words)
#     '0615': ??,   # Aspasius (1 files, 80,550 words)
#     '5037': ??,   # Scholia in Sophoclem (1 files, 79,535 words)
#     '4017': ??,   # Syrianus (1 files, 79,168 words)
#     '0658': ??,   # Heliodorus of Emesa (1 files, 76,360 words)
#     '4030': ??,   # Sophonias (1 files, 74,856 words)
#     '4024': ??,   # Agathias Scholasticus (2 files, 71,285 words)

# %% [markdown]
# ## 11. Implications for Diachronic Study
#
# Key observations to interpret from the visualizations:
#
# 1. **Corpus imbalance matters.** The 5th–4th centuries BCE and 2nd century CE
#    are likely the best-represented. Any frequency-based diachronic claims must
#    be normalized against the available corpus size per period.
#
# 2. **Genre shift over time.** The Archaic period is overwhelmingly poetry (Homer,
#    Hesiod, lyric). Prose emerges in the 5th century (Herodotus, Thucydides,
#    Hippocratic corpus) and dominates from the Hellenistic period onward.
#    This is a real historical development, but it also means that apparent
#    "linguistic change" might partly reflect genre differences.
#
# 3. **Control for genre in diachronic comparisons.** When comparing, e.g.,
#    particle usage in 5th c. BCE vs. 2nd c. CE, restrict the comparison to
#    prose-only or poetry-only subcorpora, not the full mixed data.
#
# 4. **First1KGreek fills critical gaps.** It adds substantial late antique
#    material (church fathers, commentators) that Perseus underrepresents,
#    which is essential for tracking Koine and post-Classical developments.

# %% [markdown]
# ## 9c. Quotation Tags in Prose Texts: `<quote>` vs. `<said>` / `<q>`
#
# TEI XML distinguishes between different kinds of quoted material:
#
# - **`<quote>`** — text taken from *another* document (an external citation).
# - **`<said>`** and **`<q>`** — direct or reported speech attributed to a character
#   or speaker *within* the narrative (i.e., the document author's own composition).
#
# This section counts how many works use each tag type, how frequently,
# and summarises the results by century and author.

# %%
# ── Count <quote>, <said>, and <q> elements in each text ──

def count_quotation_tags(filepath):
    """Parse a TEI XML file and return counts of <quote>, <said>, and <q>.

    Returns a dict with keys 'quote', 'said', 'q'.
    """
    counts = {'quote': 0, 'said': 0, 'q': 0}
    try:
        tree = etree.parse(filepath)
    except etree.XMLSyntaxError:
        return counts
    root = tree.getroot()

    # Find the body to exclude header metadata
    body = None
    for ns_prefix in ['{http://www.tei-c.org/ns/1.0}', '']:
        body = root.find(f'.//{ns_prefix}body')
        if body is not None:
            break
    if body is None:
        for ns_prefix in ['{http://www.tei-c.org/ns/1.0}', '']:
            body = root.find(f'.//{ns_prefix}text')
            if body is not None:
                break
    if body is None:
        return counts

    for tag in ['quote', 'said', 'q']:
        for ns_prefix in ['{http://www.tei-c.org/ns/1.0}', '']:
            n = len(body.findall(f'.//{ns_prefix}{tag}'))
            if n > 0:
                counts[tag] = n
                break
    return counts


# Resolve paths for all dated texts (not just prose this time)
df_qt = df_dated.copy()
if 'full_path' not in df_qt.columns:
    df_qt['full_path'] = df_qt.apply(resolve_filepath, axis=1)
df_qt = df_qt.dropna(subset=['full_path'])

print(f"Scanning {len(df_qt)} texts for quotation tags...")
qt_counts = df_qt['full_path'].apply(count_quotation_tags)
df_qt['n_quote'] = qt_counts.apply(lambda d: d['quote'])
df_qt['n_said']  = qt_counts.apply(lambda d: d['said'])
df_qt['n_q']     = qt_counts.apply(lambda d: d['q'])
df_qt['n_said_q'] = df_qt['n_said'] + df_qt['n_q']

# Boolean flags
df_qt['has_quote']  = df_qt['n_quote'] > 0
df_qt['has_said_q'] = df_qt['n_said_q'] > 0
df_qt['has_both']   = df_qt['has_quote'] & df_qt['has_said_q']

# ── Overall summary ──
n = len(df_qt)
n_quote  = df_qt['has_quote'].sum()
n_said_q = df_qt['has_said_q'].sum()
n_both   = df_qt['has_both'].sum()
n_either = (df_qt['has_quote'] | df_qt['has_said_q']).sum()
n_neither = n - n_either

print(f"\n── Overall tag usage across {n} dated texts ──")
print(f"  Works using <quote>          : {n_quote:>5}  ({n_quote/n*100:.1f}%)")
print(f"  Works using <said> or <q>     : {n_said_q:>5}  ({n_said_q/n*100:.1f}%)")
print(f"  Works using both              : {n_both:>5}  ({n_both/n*100:.1f}%)")
print(f"  Works using neither           : {n_neither:>5}  ({n_neither/n*100:.1f}%)")
print(f"\n  Total <quote> occurrences     : {df_qt['n_quote'].sum():>8,}")
print(f"  Total <said>/<q> occurrences  : {df_qt['n_said_q'].sum():>8,}")

# ── Per-work table: works with any quotation tags, sorted by total ──
df_qt['total_qt_tags'] = df_qt['n_quote'] + df_qt['n_said_q']
df_qt_any = df_qt[df_qt['total_qt_tags'] > 0].sort_values(
    'total_qt_tags', ascending=False
).copy()

per_work_qt = df_qt_any[['author', 'file', 'genre', 'century_label',
                          'n_quote', 'n_said', 'n_q', 'word_count']].copy()
per_work_qt.columns = ['Author', 'File', 'Genre', 'Century',
                        '<quote>', '<said>', '<q>', 'Word count']
per_work_qt = per_work_qt.reset_index(drop=True)

print(f"\n── Per-work counts ({len(per_work_qt)} texts with quotation tags) ──")
display(per_work_qt.style
        .set_properties(**{'text-align': 'left'})
        .set_table_styles([{'selector': 'th',
                            'props': [('text-align', 'left')]}])
        .format({'Word count': '{:,}', '<quote>': '{:,}',
                 '<said>': '{:,}', '<q>': '{:,}'}))

# ── Summary by century ──
cent_qt = df_qt.groupby('century').agg(
    total_texts=('file', 'count'),
    texts_with_quote=('has_quote', 'sum'),
    texts_with_said_q=('has_said_q', 'sum'),
    texts_with_both=('has_both', 'sum'),
    sum_quote=('n_quote', 'sum'),
    sum_said_q=('n_said_q', 'sum'),
).reindex(century_order, fill_value=0)

cent_qt['pct_quote']  = cent_qt['texts_with_quote']  / cent_qt['total_texts'] * 100
cent_qt['pct_said_q'] = cent_qt['texts_with_said_q'] / cent_qt['total_texts'] * 100
cent_qt.index = [century_label(c) for c in cent_qt.index]
cent_qt = cent_qt[cent_qt['total_texts'] > 0]

print("\n── Quotation tag usage by century ──")
display(cent_qt.style.format({
    'sum_quote': '{:,}', 'sum_said_q': '{:,}',
    'pct_quote': '{:.1f}%', 'pct_said_q': '{:.1f}%',
}).set_properties(**{'text-align': 'left'}))

# ── Summary by genre ──
genre_qt = df_qt.groupby('genre').agg(
    total_texts=('file', 'count'),
    texts_with_quote=('has_quote', 'sum'),
    texts_with_said_q=('has_said_q', 'sum'),
    sum_quote=('n_quote', 'sum'),
    sum_said_q=('n_said_q', 'sum'),
)
genre_qt['pct_quote']  = genre_qt['texts_with_quote']  / genre_qt['total_texts'] * 100
genre_qt['pct_said_q'] = genre_qt['texts_with_said_q'] / genre_qt['total_texts'] * 100

print("\n── Quotation tag usage by genre ──")
display(genre_qt.style.format({
    'sum_quote': '{:,}', 'sum_said_q': '{:,}',
    'pct_quote': '{:.1f}%', 'pct_said_q': '{:.1f}%',
}).set_properties(**{'text-align': 'left'}))

# ── Visualization: grouped bar chart by century ──
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 10),
                                gridspec_kw={'height_ratios': [1, 1]})

# Top: percentage of texts using each tag type
cent_plot = cent_qt.copy()
x = np.arange(len(cent_plot))
w = 0.35
ax1.bar(x - w/2, cent_plot['pct_quote'],  w, label='<quote> (external citation)',
        color='#3266ad', alpha=0.85, edgecolor='white', linewidth=0.5)
ax1.bar(x + w/2, cent_plot['pct_said_q'], w, label='<said>/<q> (direct speech)',
        color='#BA7517', alpha=0.85, edgecolor='white', linewidth=0.5)
ax1.set_xticks(x)
ax1.set_xticklabels(cent_plot.index, rotation=45, ha='right', fontsize=9)
ax1.set_ylabel('% of texts using tag')
ax1.set_title('Proportion of texts using quotation tags by century',
              fontsize=13, fontweight='bold', pad=12)
ax1.legend(frameon=False, loc='upper left')
ax1.yaxis.set_major_formatter(ticker.PercentFormatter())

# Bottom: total tag occurrences
ax2.bar(x - w/2, cent_plot['sum_quote'],  w, label='<quote> occurrences',
        color='#3266ad', alpha=0.85, edgecolor='white', linewidth=0.5)
ax2.bar(x + w/2, cent_plot['sum_said_q'], w, label='<said>/<q> occurrences',
        color='#BA7517', alpha=0.85, edgecolor='white', linewidth=0.5)
ax2.set_xticks(x)
ax2.set_xticklabels(cent_plot.index, rotation=45, ha='right', fontsize=9)
ax2.set_ylabel('Total tag occurrences')
ax2.set_title('Total quotation tag occurrences by century',
              fontsize=13, fontweight='bold', pad=12)
ax2.yaxis.set_major_formatter(
    ticker.FuncFormatter(lambda v, _: f'{v/1e3:.1f}K' if v >= 1e3 else f'{v:.0f}')
)
ax2.legend(frameon=False, loc='upper left')

plt.tight_layout()
plt.savefig('04_quotation_tags_by_century.png', dpi=150, bbox_inches='tight')
plt.show()
print("Saved: 04_quotation_tags_by_century.png")
# Out:
# Scanning 1452 texts for quotation tags...
#
# ── Overall tag usage across 1452 dated texts ──
#   Works using <quote>          :   392  (27.0%)
#   Works using <said> or <q>     :   432  (29.8%)
#   Works using both              :   270  (18.6%)
#   Works using neither           :   898  (61.8%)
#
#   Total <quote> occurrences     :   24,998
#   Total <said>/<q> occurrences  :   44,303
#
# ── Per-work counts (554 texts with quotation tags) ──
# <style type="text/css">
# #T_3f534 th {
#   text-align: left;
# }
# #T_3f534_row0_col0, #T_3f534_row0_col1, #T_3f534_row0_col2, #T_3f534_row0_col3, #T_3f534_row0_col4, #T_3f534_row0_col5, #T_3f534_row0_col6, #T_3f534_row0_col7, #T_3f534_row1_col0, #T_3f534_row1_col1, #T_3f534_row1_col2, #T_3f534_row1_col3, #T_3f534_row1_col4, #T_3f534_row1_col5, #T_3f534_row1_col6, #T_3f534_row1_col7, #T_3f534_row2_col0, #T_3f534_row2_col1, #T_3f534_row2_col2, #T_3f534_row2_col3, #T_3f534_row2_col4, #T_3f534_row2_col5, #T_3f534_row2_col6, #T_3f534_row2_col7, #T_3f534_row3_col0, #T_3f534_row3_col1, #T_3f534_row3_col2, #T_3f534_row3_col3, #T_3f534_row3_col4, #T_3f534_row3_col5, #T_3f534_row3_col6, #T_3f534_row3_col7, #T_3f534_row4_col0, #T_3f534_row4_col1, #T_3f534_row4_col2, #T_3f534_row4_col3, #T_3f534_row4_col4, #T_3f534_row4_col5, #T_3f534_row4_col6, #T_3f534_row4_col7, #T_3f534_row5_col0, #T_3f534_row5_col1, #T_3f534_row5_col2, #T_3f534_row5_col3, #T_3f534_row5_col4, #T_3f534_row5_col5, #T_3f534_row5_col6, #T_3f534_row5_col7, #T_3f534_row6_col0, #T_3f534_row6_col1, #T_3f534_row6_col2, #T_3f534_row6_col3, #T_3f534_row6_col4, #T_3f534_row6_col5, #T_3f534_row6_col6, #T_3f534_row6_col7, #T_3f534_row7_col0, #T_3f534_row7_col1, #T_3f534_row7_col2, #T_3f534_row7_col3, #T_3f534_row7_col4, #T_3f534_row7_col5, #T_3f534_row7_col6, #T_3f534_row7_col7, #T_3f534_row8_col0, #T_3f534_row8_col1, #T_3f534_row8_col2, #T_3f534_row8_col3, #T_3f534_row8_col4, #T_3f534_row8_col5, #T_3f534_row8_col6, #T_3f534_row8_col7, #T_3f534_row9_col0, #T_3f534_row9_col1, #T_3f534_row9_col2, #T_3f534_row9_col3, #T_3f534_row9_col4, #T_3f534_row9_col5, #T_3f534_row9_col6, #T_3f534_row9_col7, #T_3f534_row10_col0, #T_3f534_row10_col1, #T_3f534_row10_col2, #T_3f534_row10_col3, #T_3f534_row10_col4, #T_3f534_row10_col5, #T_3f534_row10_col6, #T_3f534_row10_col7, #T_3f534_row11_col0, #T_3f534_row11_col1, #T_3f534_row11_col2, #T_3f534_row11_col3, #T_3f534_row11_col4, #T_3f534_row11_col5, #T_3f534_row11_col6, #T_3f534_row11_col7, #T_3f534_row12_col0, #T_3f534_row12_col1, #T_3f534_row12_col2, #T_3f534_row12_col3, #T_3f534_row12_col4, #T_3f534_row12_col5, #T_3f534_row12_col6, #T_3f534_row12_col7, #T_3f534_row13_col0, #T_3f534_row13_col1, #T_3f534_row13_col2, #T_3f534_row13_col3, #T_3f534_row13_col4, #T_3f534_row13_col5, #T_3f534_row13_col6, #T_3f534_row13_col7, #T_3f534_row14_col0, #T_3f534_row14_col1, #T_3f534_row14_col2, #T_3f534_row14_col3, #T_3f534_row14_col4, #T_3f534_row14_col5, #T_3f534_row14_col6, #T_3f534_row14_col7, #T_3f534_row15_col0, #T_3f534_row15_col1, #T_3f534_row15_col2, #T_3f534_row15_col3, #T_3f534_row15_col4, #T_3f534_row15_col5, #T_3f534_row15_col6, #T_3f534_row15_col7, #T_3f534_row16_col0, #T_3f534_row16_col1, #T_3f534_row16_col2, #T_3f534_row16_col3, #T_3f534_row16_col4, #T_3f534_row16_col5, #T_3f534_row16_col6, #T_3f534_row16_col7, #T_3f534_row17_col0, #T_3f534_row17_col1, #T_3f534_row17_col2, #T_3f534_row17_col3, #T_3f534_row17_col4, #T_3f534_row17_col5, #T_3f534_row17_col6, #T_3f534_row17_col7, #T_3f534_row18_col0, #T_3f534_row18_col1, #T_3f534_row18_col2, #T_3f534_row18_col3, #T_3f534_row18_col4, #T_3f534_row18_col5, #T_3f534_row18_col6, #T_3f534_row18_col7, #T_3f534_row19_col0, #T_3f534_row19_col1, #T_3f534_row19_col2, #T_3f534_row19_col3, #T_3f534_row19_col4, #T_3f534_row19_col5, #T_3f534_row19_col6, #T_3f534_row19_col7, #T_3f534_row20_col0, #T_3f534_row20_col1, #T_3f534_row20_col2, #T_3f534_row20_col3, #T_3f534_row20_col4, #T_3f534_row20_col5, #T_3f534_row20_col6, #T_3f534_row20_col7, #T_3f534_row21_col0, #T_3f534_row21_col1, #T_3f534_row21_col2, #T_3f534_row21_col3, #T_3f534_row21_col4, #T_3f534_row21_col5, #T_3f534_row21_col6, #T_3f534_row21_col7, #T_3f534_row22_col0, #T_3f534_row22_col1, #T_3f534_row22_col2, #T_3f534_row22_col3, #T_3f534_row22_col4, #T_3f534_row22_col5, #T_3f534_row22_col6, #T_3f534_row22_col7, #T_3f534_row23_col0, #T_3f534_row23_col1, #T_3f534_row23_col2, #T_3f534_row23_col3, #T_3f534_row23_col4, #T_3f534_row23_col5, #T_3f534_row23_col6, #T_3f534_row23_col7, #T_3f534_row24_col0, #T_3f534_row24_col1, #T_3f5 ...
# ── Quotation tag usage by century ──
# <style type="text/css">
# #T_58dca_row0_col0, #T_58dca_row0_col1, #T_58dca_row0_col2, #T_58dca_row0_col3, #T_58dca_row0_col4, #T_58dca_row0_col5, #T_58dca_row0_col6, #T_58dca_row0_col7, #T_58dca_row1_col0, #T_58dca_row1_col1, #T_58dca_row1_col2, #T_58dca_row1_col3, #T_58dca_row1_col4, #T_58dca_row1_col5, #T_58dca_row1_col6, #T_58dca_row1_col7, #T_58dca_row2_col0, #T_58dca_row2_col1, #T_58dca_row2_col2, #T_58dca_row2_col3, #T_58dca_row2_col4, #T_58dca_row2_col5, #T_58dca_row2_col6, #T_58dca_row2_col7, #T_58dca_row3_col0, #T_58dca_row3_col1, #T_58dca_row3_col2, #T_58dca_row3_col3, #T_58dca_row3_col4, #T_58dca_row3_col5, #T_58dca_row3_col6, #T_58dca_row3_col7, #T_58dca_row4_col0, #T_58dca_row4_col1, #T_58dca_row4_col2, #T_58dca_row4_col3, #T_58dca_row4_col4, #T_58dca_row4_col5, #T_58dca_row4_col6, #T_58dca_row4_col7, #T_58dca_row5_col0, #T_58dca_row5_col1, #T_58dca_row5_col2, #T_58dca_row5_col3, #T_58dca_row5_col4, #T_58dca_row5_col5, #T_58dca_row5_col6, #T_58dca_row5_col7, #T_58dca_row6_col0, #T_58dca_row6_col1, #T_58dca_row6_col2, #T_58dca_row6_col3, #T_58dca_row6_col4, #T_58dca_row6_col5, #T_58dca_row6_col6, #T_58dca_row6_col7, #T_58dca_row7_col0, #T_58dca_row7_col1, #T_58dca_row7_col2, #T_58dca_row7_col3, #T_58dca_row7_col4, #T_58dca_row7_col5, #T_58dca_row7_col6, #T_58dca_row7_col7, #T_58dca_row8_col0, #T_58dca_row8_col1, #T_58dca_row8_col2, #T_58dca_row8_col3, #T_58dca_row8_col4, #T_58dca_row8_col5, #T_58dca_row8_col6, #T_58dca_row8_col7, #T_58dca_row9_col0, #T_58dca_row9_col1, #T_58dca_row9_col2, #T_58dca_row9_col3, #T_58dca_row9_col4, #T_58dca_row9_col5, #T_58dca_row9_col6, #T_58dca_row9_col7, #T_58dca_row10_col0, #T_58dca_row10_col1, #T_58dca_row10_col2, #T_58dca_row10_col3, #T_58dca_row10_col4, #T_58dca_row10_col5, #T_58dca_row10_col6, #T_58dca_row10_col7, #T_58dca_row11_col0, #T_58dca_row11_col1, #T_58dca_row11_col2, #T_58dca_row11_col3, #T_58dca_row11_col4, #T_58dca_row11_col5, #T_58dca_row11_col6, #T_58dca_row11_col7, #T_58dca_row12_col0, #T_58dca_row12_col1, #T_58dca_row12_col2, #T_58dca_row12_col3, #T_58dca_row12_col4, #T_58dca_row12_col5, #T_58dca_row12_col6, #T_58dca_row12_col7, #T_58dca_row13_col0, #T_58dca_row13_col1, #T_58dca_row13_col2, #T_58dca_row13_col3, #T_58dca_row13_col4, #T_58dca_row13_col5, #T_58dca_row13_col6, #T_58dca_row13_col7, #T_58dca_row14_col0, #T_58dca_row14_col1, #T_58dca_row14_col2, #T_58dca_row14_col3, #T_58dca_row14_col4, #T_58dca_row14_col5, #T_58dca_row14_col6, #T_58dca_row14_col7, #T_58dca_row15_col0, #T_58dca_row15_col1, #T_58dca_row15_col2, #T_58dca_row15_col3, #T_58dca_row15_col4, #T_58dca_row15_col5, #T_58dca_row15_col6, #T_58dca_row15_col7, #T_58dca_row16_col0, #T_58dca_row16_col1, #T_58dca_row16_col2, #T_58dca_row16_col3, #T_58dca_row16_col4, #T_58dca_row16_col5, #T_58dca_row16_col6, #T_58dca_row16_col7 {
#   text-align: left;
# }
# </style>
# <table id="T_58dca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_58dca_level0_col0" class="col_heading level0 col0" >total_texts</th>
#       <th id="T_58dca_level0_col1" class="col_heading level0 col1" >texts_with_quote</th>
#       <th id="T_58dca_level0_col2" class="col_heading level0 col2" >texts_with_said_q</th>
#       <th id="T_58dca_level0_col3" class="col_heading level0 col3" >texts_with_both</th>
#       <th id="T_58dca_level0_col4" class="col_heading level0 col4" >sum_quote</th>
#       <th id="T_58dca_level0_col5" class="col_heading level0 col5" >sum_said_q</th>
#       <th id="T_58dca_level0_col6" class="col_heading level0 col6" >pct_quote</th>
#       <th id="T_58dca_level0_col7" class="col_heading level0 col7" >pct_said_q</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_58dca_level0_row0" class="row_heading level0 row0" >8th c. BCE</th>
#       <td id="T_58dca_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_58dca_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_58dca_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_58dca_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_58dca_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_58dca_row0_col5" class="data row0 col5" >1,370</td>
#       <td id="T_58dca_row0_col6" class="data row0 col6" >0.0%</td>
#       <td id="T_58dca_row0_col7" class="data row0 col7" >66.7%</td>
#     </tr>
#     <tr>
#       <th id="T_58dca_level0_row1" class="row_heading level0 row1" >7th c. BCE</th>
#       <td id="T_58dca_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_58dca_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_58dca_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_58dca_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_58dca_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_58dca_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_58dca_row1_col6" class="data row1 col6" >0.0%</td>
#       <td id="T_58dca_row1_col7" class="data row1 col7" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_58dca_level0_row2" class="row_heading level0 row2" >6th c. BCE</th>
#       <td id="T_58dca_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_58dca_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_58dca_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_58dca_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_58dca_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_58dca_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_58dca_row2_col6" class="data row2 col6" >0.0%</td>
#       <td id="T_58dca_row2_col7" class="data row2 col7" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_58dca_level0_row3" class="row_heading level0 row3" >5th c. BCE</th>
#       <td id="T_58dca_row3_col0" class="data row3 col0" >221</td>
#       <td id="T_58dca_row3_col1" class="data row3 col1" >14</td>
#       <td id="T_58dca_row3_col2" class="data row3 col2" >50</td>
#       <td id="T_58dca_row3_col3" class="data row3 col3" >9</td>
#       <td id="T_58dca_row3_col4" class="data row3 col4" >332</td>
#       <td id="T_58dca_row3_col5" class="data row3 col5" >2,327</td>
#       <td id="T_58dca_row3_col6" class="data row3 col6" >6.3%</td>
#       <td id="T_58dca_row3_col7" class="data row3 col7" >22.6%</td>
#     </tr>
#     <tr>
#       <th id="T_58dca_level0_row4" class="row_heading level0 row4" >4th c. BCE</th>
#       <td id="T_58dca_row4_col0" class="data row4 col0" >384</td>
#       <td id="T_58dca_row4_col1" class="data row4 col1" >198</td>
#       <td id="T_58dca_row4_col2" class="data row4 col2" >232</td>
#       <td id="T_58dca_row4_col3" class="data row4 col3" >174</td>
#       <td id="T_58dca_row4_col4" class="data row4 col4" >2,686</td>
#       <td id="T_58dca_row4_col5" class="data row4 col5" >26,356</td>
#       <td id="T_58dca_row4_col6" class="data row4 col6" >51.6%</td>
#       <td id="T_58dca_row4_col7" class="data row4 col7" >60.4%</td>
#     </tr>
#     <tr>
#       <th id="T_58dca_level0_row5" class="row_heading level0 row5" >3rd c. BCE</th>
#       <td id="T_58dca_row5_col0" class="data row5 col0" >44</td>
#       <td id="T_58dca_row5_col1" class="data row5 col1" >7</td>
#       <td id="T_58dca_row5_col2" class="data row5 col2" >24</td>
#       <td id="T_58dca_row5_col3" class="data row5 col3" >7</td>
#       <td id="T_58dca_row5_col4" class="data row5 col4" >452</td>
#       <td id="T_58dca_row5_col5" class="data row5 col5" >3,307</td>
#       <td id="T_58dca_row5_col6" class="data row5 col6" >15.9%</td>
#       <td id="T_58dca_row5_col7" class="data row5 col7" >54.5%</td>
#     </tr>
#     <tr>
#       <th id="T_58dca_level0_row6" class="row_heading level0 row6" >2nd c. BCE</th>
#       <td id="T_58dca_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_58dca_row6_col1" class="data row6 col1" >2</td>
#       <td id="T_58dca_row6_col2" class="data row6 col2" >3</td>
#       <td id="T_58dca_row6_col3" class="data row6 col3" >2</td>
#       <td id="T_58dca_row6_col4" class="data row6 col4" >39</td>
#       <td id="T_58dca_row6_col5" class="data row6 col5" >1,087</td>
#       <td id="T_58dca_row6_col6" class="data row6 col6" >28.6%</td>
#       <td id="T_58dca_row6_col7" class="dat
# ── Quotation tag usage by genre ──
# <style type="text/css">
# #T_9b413_row0_col0, #T_9b413_row0_col1, #T_9b413_row0_col2, #T_9b413_row0_col3, #T_9b413_row0_col4, #T_9b413_row0_col5, #T_9b413_row0_col6, #T_9b413_row1_col0, #T_9b413_row1_col1, #T_9b413_row1_col2, #T_9b413_row1_col3, #T_9b413_row1_col4, #T_9b413_row1_col5, #T_9b413_row1_col6, #T_9b413_row2_col0, #T_9b413_row2_col1, #T_9b413_row2_col2, #T_9b413_row2_col3, #T_9b413_row2_col4, #T_9b413_row2_col5, #T_9b413_row2_col6 {
#   text-align: left;
# }
# </style>
# <table id="T_9b413">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9b413_level0_col0" class="col_heading level0 col0" >total_texts</th>
#       <th id="T_9b413_level0_col1" class="col_heading level0 col1" >texts_with_quote</th>
#       <th id="T_9b413_level0_col2" class="col_heading level0 col2" >texts_with_said_q</th>
#       <th id="T_9b413_level0_col3" class="col_heading level0 col3" >sum_quote</th>
#       <th id="T_9b413_level0_col4" class="col_heading level0 col4" >sum_said_q</th>
#       <th id="T_9b413_level0_col5" class="col_heading level0 col5" >pct_quote</th>
#       <th id="T_9b413_level0_col6" class="col_heading level0 col6" >pct_said_q</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >genre</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9b413_level0_row0" class="row_heading level0 row0" >mixed</th>
#       <td id="T_9b413_row0_col0" class="data row0 col0" >94</td>
#       <td id="T_9b413_row0_col1" class="data row0 col1" >56</td>
#       <td id="T_9b413_row0_col2" class="data row0 col2" >49</td>
#       <td id="T_9b413_row0_col3" class="data row0 col3" >2,167</td>
#       <td id="T_9b413_row0_col4" class="data row0 col4" >5,775</td>
#       <td id="T_9b413_row0_col5" class="data row0 col5" >59.6%</td>
#       <td id="T_9b413_row0_col6" class="data row0 col6" >52.1%</td>
#     </tr>
#     <tr>
#       <th id="T_9b413_level0_row1" class="row_heading level0 row1" >poetry</th>
#       <td id="T_9b413_row1_col0" class="data row1 col0" >160</td>
#       <td id="T_9b413_row1_col1" class="data row1 col1" >23</td>
#       <td id="T_9b413_row1_col2" class="data row1 col2" >63</td>
#       <td id="T_9b413_row1_col3" class="data row1 col3" >3,911</td>
#       <td id="T_9b413_row1_col4" class="data row1 col4" >3,851</td>
#       <td id="T_9b413_row1_col5" class="data row1 col5" >14.4%</td>
#       <td id="T_9b413_row1_col6" class="data row1 col6" >39.4%</td>
#     </tr>
#     <tr>
#       <th id="T_9b413_level0_row2" class="row_heading level0 row2" >prose</th>
#       <td id="T_9b413_row2_col0" class="data row2 col0" >1198</td>
#       <td id="T_9b413_row2_col1" class="data row2 col1" >313</td>
#       <td id="T_9b413_row2_col2" class="data row2 col2" >320</td>
#       <td id="T_9b413_row2_col3" class="data row2 col3" >18,920</td>
#       <td id="T_9b413_row2_col4" class="data row2 col4" >34,677</td>
#       <td id="T_9b413_row2_col5" class="data row2 col5" >26.1%</td>
#       <td id="T_9b413_row2_col6" class="data row2 col6" >26.7%</td>
#     </tr>
#   </tbody>
# </table>
# Saved: 04_quotation_tags_by_century.png

# %%
# ── Count <quote>, <said>, and <q> elements in each text ──

def count_quotation_tags(filepath):
    """Parse a TEI XML file and return counts and word counts for
    <quote>, <said>, and <q> elements.

    Returns a dict with keys:
      'quote', 'said', 'q'                    – element counts
      'quote_words', 'said_words', 'q_words'   – Greek word counts inside each
    """
    greek_pattern = re.compile(r'[\u0370-\u03FF\u1F00-\u1FFF]')
    counts = {'quote': 0, 'said': 0, 'q': 0,
              'quote_words': 0, 'said_words': 0, 'q_words': 0}
    try:
        tree = etree.parse(filepath)
    except etree.XMLSyntaxError:
        return counts
    root = tree.getroot()

    # Find the body to exclude header metadata
    body = None
    for ns_prefix in ['{http://www.tei-c.org/ns/1.0}', '']:
        body = root.find(f'.//{ns_prefix}body')
        if body is not None:
            break
    if body is None:
        for ns_prefix in ['{http://www.tei-c.org/ns/1.0}', '']:
            body = root.find(f'.//{ns_prefix}text')
            if body is not None:
                break
    if body is None:
        return counts

    for tag in ['quote', 'said', 'q']:
        for ns_prefix in ['{http://www.tei-c.org/ns/1.0}', '']:
            elements = body.findall(f'.//{ns_prefix}{tag}')
            if elements:
                counts[tag] = len(elements)
                words = 0
                for el in elements:
                    text = ''.join(el.itertext())
                    words += sum(1 for w in text.split()
                                 if greek_pattern.search(w))
                counts[f'{tag}_words'] = words
                break
    return counts


# Resolve paths for all dated texts (not just prose this time)
df_qt = df_dated.copy()
if 'full_path' not in df_qt.columns:
    df_qt['full_path'] = df_qt.apply(resolve_filepath, axis=1)
df_qt = df_qt.dropna(subset=['full_path'])

print(f"Scanning {len(df_qt)} texts for quotation tags...")
qt_counts = df_qt['full_path'].apply(count_quotation_tags)
df_qt['n_quote'] = qt_counts.apply(lambda d: d['quote'])
df_qt['n_said']  = qt_counts.apply(lambda d: d['said'])
df_qt['n_q']     = qt_counts.apply(lambda d: d['q'])
df_qt['n_said_q'] = df_qt['n_said'] + df_qt['n_q']

# Word counts inside each tag type
df_qt['words_in_quote']  = qt_counts.apply(lambda d: d['quote_words'])
df_qt['words_in_said']   = qt_counts.apply(lambda d: d['said_words'])
df_qt['words_in_q']      = qt_counts.apply(lambda d: d['q_words'])
df_qt['words_in_said_q'] = df_qt['words_in_said'] + df_qt['words_in_q']

# Percentage of each work's text that lives inside quotation tags
df_qt['pct_quote_words']  = (
    df_qt['words_in_quote'] / df_qt['word_count'].replace(0, float('nan')) * 100
)
df_qt['pct_said_q_words'] = (
    df_qt['words_in_said_q'] / df_qt['word_count'].replace(0, float('nan')) * 100
)

# Boolean flags
df_qt['has_quote']  = df_qt['n_quote'] > 0
df_qt['has_said_q'] = df_qt['n_said_q'] > 0
df_qt['has_both']   = df_qt['has_quote'] & df_qt['has_said_q']

# ── Overall summary ──
n = len(df_qt)
n_quote  = df_qt['has_quote'].sum()
n_said_q = df_qt['has_said_q'].sum()
n_both   = df_qt['has_both'].sum()
n_either = (df_qt['has_quote'] | df_qt['has_said_q']).sum()
n_neither = n - n_either
total_words_all = df_qt['word_count'].sum()

print(f"\n── Overall tag usage across {n} dated texts ──")
print(f"  Works using <quote>          : {n_quote:>5}  ({n_quote/n*100:.1f}%)")
print(f"  Works using <said> or <q>     : {n_said_q:>5}  ({n_said_q/n*100:.1f}%)")
print(f"  Works using both              : {n_both:>5}  ({n_both/n*100:.1f}%)")
print(f"  Works using neither           : {n_neither:>5}  ({n_neither/n*100:.1f}%)")
print(f"\n  Total <quote> occurrences     : {df_qt['n_quote'].sum():>8,}")
print(f"  Total <said>/<q> occurrences  : {df_qt['n_said_q'].sum():>8,}")
print(f"\n  Words inside <quote> tags     : {df_qt['words_in_quote'].sum():>8,}  "
      f"({df_qt['words_in_quote'].sum()/total_words_all*100:.1f}% of corpus)")
print(f"  Words inside <said>/<q> tags  : {df_qt['words_in_said_q'].sum():>8,}  "
      f"({df_qt['words_in_said_q'].sum()/total_words_all*100:.1f}% of corpus)")

# ── Per-work table: works with any quotation tags, sorted by total ──
df_qt['total_qt_tags'] = df_qt['n_quote'] + df_qt['n_said_q']
df_qt_any = df_qt[df_qt['total_qt_tags'] > 0].sort_values(
    'total_qt_tags', ascending=False
).copy()

per_work_qt = df_qt_any[['author', 'file', 'genre', 'century_label',
                          'n_quote', 'words_in_quote',
                          'n_said', 'n_q', 'words_in_said_q',
                          'word_count',
                          'pct_quote_words', 'pct_said_q_words']].copy()
per_work_qt.columns = ['Author', 'File', 'Genre', 'Century',
                        '`<quote>` tags', 'Words in `\<quote\>`',
                        '\<said\> tags', '\<q\> tags', 'Words in `\<said\>`/`\<q\>`',
                        'Total words',
                        '% in \<quote\>', '% in \<said\>/\<q\>']
per_work_qt = per_work_qt.reset_index(drop=True)

print(f"\n── Per-work counts ({len(per_work_qt)} texts with quotation tags) ──")
display(per_work_qt.style
        .set_properties(**{'text-align': 'left'})
        .set_table_styles([{'selector': 'th',
                            'props': [('text-align', 'left')]}])
        .format({'Total words': '{:,}',
                 '`<quote>` tags': '{:,}', 'Words in `<quote>`': '{:,}',
                 '`<said>` tags': '{:,}', '`<q>` tags': '{:,}',
                 'Words in `<said>`/`<q>`': '{:,}',
                 '% in `<quote>`': '{:.1f}%',
                 '% in `<said>`/`<q>`': '{:.1f}%'}))

# ── Summary by century ──
cent_qt = df_qt.groupby('century').agg(
    total_texts=('file', 'count'),
    texts_with_quote=('has_quote', 'sum'),
    texts_with_said_q=('has_said_q', 'sum'),
    texts_with_both=('has_both', 'sum'),
    sum_quote=('n_quote', 'sum'),
    sum_said_q=('n_said_q', 'sum'),
    sum_quote_words=('words_in_quote', 'sum'),
    sum_said_q_words=('words_in_said_q', 'sum'),
    sum_total_words=('word_count', 'sum'),
).reindex(century_order, fill_value=0)

cent_qt['pct_quote']  = cent_qt['texts_with_quote']  / cent_qt['total_texts'] * 100
cent_qt['pct_said_q'] = cent_qt['texts_with_said_q'] / cent_qt['total_texts'] * 100
cent_qt['pct_words_in_quote'] = (
    cent_qt['sum_quote_words'] / cent_qt['sum_total_words'].replace(0, float('nan')) * 100
)
cent_qt['pct_words_in_said_q'] = (
    cent_qt['sum_said_q_words'] / cent_qt['sum_total_words'].replace(0, float('nan')) * 100
)
cent_qt.index = [century_label(c) for c in cent_qt.index]
cent_qt = cent_qt[cent_qt['total_texts'] > 0]

print("\n── Quotation tag usage by century ──")
display(cent_qt.style.format({
    'sum_quote': '{:,}', 'sum_said_q': '{:,}',
    'sum_quote_words': '{:,}', 'sum_said_q_words': '{:,}',
    'sum_total_words': '{:,}',
    'pct_quote': '{:.1f}%', 'pct_said_q': '{:.1f}%',
    'pct_words_in_quote': '{:.1f}%', 'pct_words_in_said_q': '{:.1f}%',
}).set_properties(**{'text-align': 'left'}))

# ── Summary by genre ──
genre_qt = df_qt.groupby('genre').agg(
    total_texts=('file', 'count'),
    texts_with_quote=('has_quote', 'sum'),
    texts_with_said_q=('has_said_q', 'sum'),
    sum_quote=('n_quote', 'sum'),
    sum_said_q=('n_said_q', 'sum'),
    sum_quote_words=('words_in_quote', 'sum'),
    sum_said_q_words=('words_in_said_q', 'sum'),
    sum_total_words=('word_count', 'sum'),
)
genre_qt['pct_quote']  = genre_qt['texts_with_quote']  / genre_qt['total_texts'] * 100
genre_qt['pct_said_q'] = genre_qt['texts_with_said_q'] / genre_qt['total_texts'] * 100
genre_qt['pct_words_in_quote'] = (
    genre_qt['sum_quote_words'] / genre_qt['sum_total_words'].replace(0, float('nan')) * 100
)
genre_qt['pct_words_in_said_q'] = (
    genre_qt['sum_said_q_words'] / genre_qt['sum_total_words'].replace(0, float('nan')) * 100
)

print("\n── Quotation tag usage by genre ──")
display(genre_qt.style.format({
    'sum_quote': '{:,}', 'sum_said_q': '{:,}',
    'sum_quote_words': '{:,}', 'sum_said_q_words': '{:,}',
    'sum_total_words': '{:,}',
    'pct_quote': '{:.1f}%', 'pct_said_q': '{:.1f}%',
    'pct_words_in_quote': '{:.1f}%', 'pct_words_in_said_q': '{:.1f}%',
}).set_properties(**{'text-align': 'left'}))

# ── Visualization: grouped bar chart by century ──
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 10),
                                gridspec_kw={'height_ratios': [1, 1]})

# Top: percentage of each century's words inside each tag type
cent_plot = cent_qt.copy()
x = np.arange(len(cent_plot))
w = 0.35
ax1.bar(x - w/2, cent_plot['pct_words_in_quote'],  w,
        label='% of words in \<quote\> (external citation)',
        color='#3266ad', alpha=0.85, edgecolor='white', linewidth=0.5)
ax1.bar(x + w/2, cent_plot['pct_words_in_said_q'], w,
        label='% of words in <said>/<q> (direct speech)',
        color='#BA7517', alpha=0.85, edgecolor='white', linewidth=0.5)
ax1.set_xticks(x)
ax1.set_xticklabels(cent_plot.index, rotation=45, ha='right', fontsize=9)
ax1.set_ylabel('% of century\'s total words')
ax1.set_title('Share of text inside quotation tags by century',
              fontsize=13, fontweight='bold', pad=12)
ax1.legend(frameon=False, loc='upper left')
ax1.yaxis.set_major_formatter(ticker.PercentFormatter())

# Bottom: absolute word counts inside tags
ax2.bar(x - w/2, cent_plot['sum_quote_words'],  w,
        label='Words in \<quote>',
        color='#3266ad', alpha=0.85, edgecolor='white', linewidth=0.5)
ax2.bar(x + w/2, cent_plot['sum_said_q_words'], w,
        label='Words in \<said>/\<q>',
        color='#BA7517', alpha=0.85, edgecolor='white', linewidth=0.5)
ax2.set_xticks(x)
ax2.set_xticklabels(cent_plot.index, rotation=45, ha='right', fontsize=9)
ax2.set_ylabel('Word count inside tags')
ax2.set_title('Total words inside quotation tags by century',
              fontsize=13, fontweight='bold', pad=12)
ax2.yaxis.set_major_formatter(
    ticker.FuncFormatter(lambda v, _: f'{v/1e3:.1f}K' if v >= 1e3 else f'{v:.0f}')
)
ax2.legend(frameon=False, loc='upper left')

plt.tight_layout()
plt.savefig('04_quotation_tags_by_century.png', dpi=150, bbox_inches='tight')
plt.show()
print("Saved: 04_quotation_tags_by_century.png")
# Out:
# Scanning 1452 texts for quotation tags...
#
# ── Overall tag usage across 1452 dated texts ──
#   Works using <quote>          :   392  (27.0%)
#   Works using <said> or <q>     :   432  (29.8%)
#   Works using both              :   270  (18.6%)
#   Works using neither           :   898  (61.8%)
#
#   Total <quote> occurrences     :   24,998
#   Total <said>/<q> occurrences  :   44,303
#
#   Words inside <quote> tags     :  548,233  (1.8% of corpus)
#   Words inside <said>/<q> tags  : 1,319,724  (4.4% of corpus)
#
# ── Per-work counts (554 texts with quotation tags) ──
# <style type="text/css">
# #T_6abcc th {
#   text-align: left;
# }
# #T_6abcc_row0_col0, #T_6abcc_row0_col1, #T_6abcc_row0_col2, #T_6abcc_row0_col3, #T_6abcc_row0_col4, #T_6abcc_row0_col5, #T_6abcc_row0_col6, #T_6abcc_row0_col7, #T_6abcc_row0_col8, #T_6abcc_row0_col9, #T_6abcc_row0_col10, #T_6abcc_row0_col11, #T_6abcc_row1_col0, #T_6abcc_row1_col1, #T_6abcc_row1_col2, #T_6abcc_row1_col3, #T_6abcc_row1_col4, #T_6abcc_row1_col5, #T_6abcc_row1_col6, #T_6abcc_row1_col7, #T_6abcc_row1_col8, #T_6abcc_row1_col9, #T_6abcc_row1_col10, #T_6abcc_row1_col11, #T_6abcc_row2_col0, #T_6abcc_row2_col1, #T_6abcc_row2_col2, #T_6abcc_row2_col3, #T_6abcc_row2_col4, #T_6abcc_row2_col5, #T_6abcc_row2_col6, #T_6abcc_row2_col7, #T_6abcc_row2_col8, #T_6abcc_row2_col9, #T_6abcc_row2_col10, #T_6abcc_row2_col11, #T_6abcc_row3_col0, #T_6abcc_row3_col1, #T_6abcc_row3_col2, #T_6abcc_row3_col3, #T_6abcc_row3_col4, #T_6abcc_row3_col5, #T_6abcc_row3_col6, #T_6abcc_row3_col7, #T_6abcc_row3_col8, #T_6abcc_row3_col9, #T_6abcc_row3_col10, #T_6abcc_row3_col11, #T_6abcc_row4_col0, #T_6abcc_row4_col1, #T_6abcc_row4_col2, #T_6abcc_row4_col3, #T_6abcc_row4_col4, #T_6abcc_row4_col5, #T_6abcc_row4_col6, #T_6abcc_row4_col7, #T_6abcc_row4_col8, #T_6abcc_row4_col9, #T_6abcc_row4_col10, #T_6abcc_row4_col11, #T_6abcc_row5_col0, #T_6abcc_row5_col1, #T_6abcc_row5_col2, #T_6abcc_row5_col3, #T_6abcc_row5_col4, #T_6abcc_row5_col5, #T_6abcc_row5_col6, #T_6abcc_row5_col7, #T_6abcc_row5_col8, #T_6abcc_row5_col9, #T_6abcc_row5_col10, #T_6abcc_row5_col11, #T_6abcc_row6_col0, #T_6abcc_row6_col1, #T_6abcc_row6_col2, #T_6abcc_row6_col3, #T_6abcc_row6_col4, #T_6abcc_row6_col5, #T_6abcc_row6_col6, #T_6abcc_row6_col7, #T_6abcc_row6_col8, #T_6abcc_row6_col9, #T_6abcc_row6_col10, #T_6abcc_row6_col11, #T_6abcc_row7_col0, #T_6abcc_row7_col1, #T_6abcc_row7_col2, #T_6abcc_row7_col3, #T_6abcc_row7_col4, #T_6abcc_row7_col5, #T_6abcc_row7_col6, #T_6abcc_row7_col7, #T_6abcc_row7_col8, #T_6abcc_row7_col9, #T_6abcc_row7_col10, #T_6abcc_row7_col11, #T_6abcc_row8_col0, #T_6abcc_row8_col1, #T_6abcc_row8_col2, #T_6abcc_row8_col3, #T_6abcc_row8_col4, #T_6abcc_row8_col5, #T_6abcc_row8_col6, #T_6abcc_row8_col7, #T_6abcc_row8_col8, #T_6abcc_row8_col9, #T_6abcc_row8_col10, #T_6abcc_row8_col11, #T_6abcc_row9_col0, #T_6abcc_row9_col1, #T_6abcc_row9_col2, #T_6abcc_row9_col3, #T_6abcc_row9_col4, #T_6abcc_row9_col5, #T_6abcc_row9_col6, #T_6abcc_row9_col7, #T_6abcc_row9_col8, #T_6abcc_row9_col9, #T_6abcc_row9_col10, #T_6abcc_row9_col11, #T_6abcc_row10_col0, #T_6abcc_row10_col1, #T_6abcc_row10_col2, #T_6abcc_row10_col3, #T_6abcc_row10_col4, #T_6abcc_row10_col5, #T_6abcc_row10_col6, #T_6abcc_row10_col7, #T_6abcc_row10_col8, #T_6abcc_row10_col9, #T_6abcc_row10_col10, #T_6abcc_row10_col11, #T_6abcc_row11_col0, #T_6abcc_row11_col1, #T_6abcc_row11_col2, #T_6abcc_row11_col3, #T_6abcc_row11_col4, #T_6abcc_row11_col5, #T_6abcc_row11_col6, #T_6abcc_row11_col7, #T_6abcc_row11_col8, #T_6abcc_row11_col9, #T_6abcc_row11_col10, #T_6abcc_row11_col11, #T_6abcc_row12_col0, #T_6abcc_row12_col1, #T_6abcc_row12_col2, #T_6abcc_row12_col3, #T_6abcc_row12_col4, #T_6abcc_row12_col5, #T_6abcc_row12_col6, #T_6abcc_row12_col7, #T_6abcc_row12_col8, #T_6abcc_row12_col9, #T_6abcc_row12_col10, #T_6abcc_row12_col11, #T_6abcc_row13_col0, #T_6abcc_row13_col1, #T_6abcc_row13_col2, #T_6abcc_row13_col3, #T_6abcc_row13_col4, #T_6abcc_row13_col5, #T_6abcc_row13_col6, #T_6abcc_row13_col7, #T_6abcc_row13_col8, #T_6abcc_row13_col9, #T_6abcc_row13_col10, #T_6abcc_row13_col11, #T_6abcc_row14_col0, #T_6abcc_row14_col1, #T_6abcc_row14_col2, #T_6abcc_row14_col3, #T_6abcc_row14_col4, #T_6abcc_row14_col5, #T_6abcc_row14_col6, #T_6abcc_row14_col7, #T_6abcc_row14_col8, #T_6abcc_row14_col9, #T_6abcc_row14_col10, #T_6abcc_row14_col11, #T_6abcc_row15_col0, #T_6abcc_row15_col1, #T_6abcc_row15_col2, #T_6abcc_row15_col3, #T_6abcc_row15_col4, #T_6abcc_row15_col5, #T_6abcc_row15_col6, #T_6abcc_row15_col7, #T_6abcc_row15_col8, #T_6abcc_row15_col9, #T_6abcc_row15_col10, #T_6abcc_row15_col11, #T_6abcc_row16_col0, #T_6abcc_row16_col1, #T_6abcc_row16 ...
# ── Quotation tag usage by century ──
# <style type="text/css">
# #T_f4562_row0_col0, #T_f4562_row0_col1, #T_f4562_row0_col2, #T_f4562_row0_col3, #T_f4562_row0_col4, #T_f4562_row0_col5, #T_f4562_row0_col6, #T_f4562_row0_col7, #T_f4562_row0_col8, #T_f4562_row0_col9, #T_f4562_row0_col10, #T_f4562_row0_col11, #T_f4562_row0_col12, #T_f4562_row1_col0, #T_f4562_row1_col1, #T_f4562_row1_col2, #T_f4562_row1_col3, #T_f4562_row1_col4, #T_f4562_row1_col5, #T_f4562_row1_col6, #T_f4562_row1_col7, #T_f4562_row1_col8, #T_f4562_row1_col9, #T_f4562_row1_col10, #T_f4562_row1_col11, #T_f4562_row1_col12, #T_f4562_row2_col0, #T_f4562_row2_col1, #T_f4562_row2_col2, #T_f4562_row2_col3, #T_f4562_row2_col4, #T_f4562_row2_col5, #T_f4562_row2_col6, #T_f4562_row2_col7, #T_f4562_row2_col8, #T_f4562_row2_col9, #T_f4562_row2_col10, #T_f4562_row2_col11, #T_f4562_row2_col12, #T_f4562_row3_col0, #T_f4562_row3_col1, #T_f4562_row3_col2, #T_f4562_row3_col3, #T_f4562_row3_col4, #T_f4562_row3_col5, #T_f4562_row3_col6, #T_f4562_row3_col7, #T_f4562_row3_col8, #T_f4562_row3_col9, #T_f4562_row3_col10, #T_f4562_row3_col11, #T_f4562_row3_col12, #T_f4562_row4_col0, #T_f4562_row4_col1, #T_f4562_row4_col2, #T_f4562_row4_col3, #T_f4562_row4_col4, #T_f4562_row4_col5, #T_f4562_row4_col6, #T_f4562_row4_col7, #T_f4562_row4_col8, #T_f4562_row4_col9, #T_f4562_row4_col10, #T_f4562_row4_col11, #T_f4562_row4_col12, #T_f4562_row5_col0, #T_f4562_row5_col1, #T_f4562_row5_col2, #T_f4562_row5_col3, #T_f4562_row5_col4, #T_f4562_row5_col5, #T_f4562_row5_col6, #T_f4562_row5_col7, #T_f4562_row5_col8, #T_f4562_row5_col9, #T_f4562_row5_col10, #T_f4562_row5_col11, #T_f4562_row5_col12, #T_f4562_row6_col0, #T_f4562_row6_col1, #T_f4562_row6_col2, #T_f4562_row6_col3, #T_f4562_row6_col4, #T_f4562_row6_col5, #T_f4562_row6_col6, #T_f4562_row6_col7, #T_f4562_row6_col8, #T_f4562_row6_col9, #T_f4562_row6_col10, #T_f4562_row6_col11, #T_f4562_row6_col12, #T_f4562_row7_col0, #T_f4562_row7_col1, #T_f4562_row7_col2, #T_f4562_row7_col3, #T_f4562_row7_col4, #T_f4562_row7_col5, #T_f4562_row7_col6, #T_f4562_row7_col7, #T_f4562_row7_col8, #T_f4562_row7_col9, #T_f4562_row7_col10, #T_f4562_row7_col11, #T_f4562_row7_col12, #T_f4562_row8_col0, #T_f4562_row8_col1, #T_f4562_row8_col2, #T_f4562_row8_col3, #T_f4562_row8_col4, #T_f4562_row8_col5, #T_f4562_row8_col6, #T_f4562_row8_col7, #T_f4562_row8_col8, #T_f4562_row8_col9, #T_f4562_row8_col10, #T_f4562_row8_col11, #T_f4562_row8_col12, #T_f4562_row9_col0, #T_f4562_row9_col1, #T_f4562_row9_col2, #T_f4562_row9_col3, #T_f4562_row9_col4, #T_f4562_row9_col5, #T_f4562_row9_col6, #T_f4562_row9_col7, #T_f4562_row9_col8, #T_f4562_row9_col9, #T_f4562_row9_col10, #T_f4562_row9_col11, #T_f4562_row9_col12, #T_f4562_row10_col0, #T_f4562_row10_col1, #T_f4562_row10_col2, #T_f4562_row10_col3, #T_f4562_row10_col4, #T_f4562_row10_col5, #T_f4562_row10_col6, #T_f4562_row10_col7, #T_f4562_row10_col8, #T_f4562_row10_col9, #T_f4562_row10_col10, #T_f4562_row10_col11, #T_f4562_row10_col12, #T_f4562_row11_col0, #T_f4562_row11_col1, #T_f4562_row11_col2, #T_f4562_row11_col3, #T_f4562_row11_col4, #T_f4562_row11_col5, #T_f4562_row11_col6, #T_f4562_row11_col7, #T_f4562_row11_col8, #T_f4562_row11_col9, #T_f4562_row11_col10, #T_f4562_row11_col11, #T_f4562_row11_col12, #T_f4562_row12_col0, #T_f4562_row12_col1, #T_f4562_row12_col2, #T_f4562_row12_col3, #T_f4562_row12_col4, #T_f4562_row12_col5, #T_f4562_row12_col6, #T_f4562_row12_col7, #T_f4562_row12_col8, #T_f4562_row12_col9, #T_f4562_row12_col10, #T_f4562_row12_col11, #T_f4562_row12_col12, #T_f4562_row13_col0, #T_f4562_row13_col1, #T_f4562_row13_col2, #T_f4562_row13_col3, #T_f4562_row13_col4, #T_f4562_row13_col5, #T_f4562_row13_col6, #T_f4562_row13_col7, #T_f4562_row13_col8, #T_f4562_row13_col9, #T_f4562_row13_col10, #T_f4562_row13_col11, #T_f4562_row13_col12, #T_f4562_row14_col0, #T_f4562_row14_col1, #T_f4562_row14_col2, #T_f4562_row14_col3, #T_f4562_row14_col4, #T_f4562_row14_col5, #T_f4562_row14_col6, #T_f4562_row14_col7, #T_f4562_row14_col8, #T_f4562_row14_col9, #T_f4562_row14_col10, #T_f4562_row14_col11, #T_f4562_row ...
#   text-align: left;
# }
# </style>
# <table id="T_f4562">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f4562_level0_col0" class="col_heading level0 col0" >total_texts</th>
#       <th id="T_f4562_level0_col1" class="col_heading level0 col1" >texts_with_quote</th>
#       <th id="T_f4562_level0_col2" class="col_heading level0 col2" >texts_with_said_q</th>
#       <th id="T_f4562_level0_col3" class="col_heading level0 col3" >texts_with_both</th>
#       <th id="T_f4562_level0_col4" class="col_heading level0 col4" >sum_quote</th>
#       <th id="T_f4562_level0_col5" class="col_heading level0 col5" >sum_said_q</th>
#       <th id="T_f4562_level0_col6" class="col_heading level0 col6" >sum_quote_words</th>
#       <th id="T_f4562_level0_col7" class="col_heading level0 col7" >sum_said_q_words</th>
#       <th id="T_f4562_level0_col8" class="col_heading level0 col8" >sum_total_words</th>
#       <th id="T_f4562_level0_col9" class="col_heading level0 col9" >pct_quote</th>
#       <th id="T_f4562_level0_col10" class="col_heading level0 col10" >pct_said_q</th>
#       <th id="T_f4562_level0_col11" class="col_heading level0 col11" >pct_words_in_quote</th>
#       <th id="T_f4562_level0_col12" class="col_heading level0 col12" >pct_words_in_said_q</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f4562_level0_row0" class="row_heading level0 row0" >8th c. BCE</th>
#       <td id="T_f4562_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_f4562_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_f4562_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_f4562_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_f4562_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_f4562_row0_col5" class="data row0 col5" >1,370</td>
#       <td id="T_f4562_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_f4562_row0_col7" class="data row0 col7" >117,451</td>
#       <td id="T_f4562_row0_col8" class="data row0 col8" >199,823</td>
#       <td id="T_f4562_row0_col9" class="data row0 col9" >0.0%</td>
#       <td id="T_f4562_row0_col10" class="data row0 col10" >66.7%</td>
#       <td id="T_f4562_row0_col11" class="data row0 col11" >0.0%</td>
#       <td id="T_f4562_row0_col12" class="data row0 col12" >58.8%</td>
#     </tr>
#     <tr>
#       <th id="T_f4562_level0_row1" class="row_heading level0 row1" >7th c. BCE</th>
#       <td id="T_f4562_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_f4562_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_f4562_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_f4562_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_f4562_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_f4562_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_f4562_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_f4562_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_f4562_row1_col8" class="data row1 col8" >16,193</td>
#       <td id="T_f4562_row1_col9" class="data row1 col9" >0.0%</td>
#       <td id="T_f4562_row1_col10" class="data row1 col10" >0.0%</td>
#       <td id="T_f4562_row1_col11" class="data row1 col11" >0.0%</td>
#       <td id="T_f4562_row1_col12" class="data row1 col12" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_f4562_level0_row2" class="row_heading level0 row2" >6th c. BCE</th>
#       <td id="T_f4562_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_f4562_row2_col1"
# ── Quotation tag usage by genre ──
# <style type="text/css">
# #T_be672_row0_col0, #T_be672_row0_col1, #T_be672_row0_col2, #T_be672_row0_col3, #T_be672_row0_col4, #T_be672_row0_col5, #T_be672_row0_col6, #T_be672_row0_col7, #T_be672_row0_col8, #T_be672_row0_col9, #T_be672_row0_col10, #T_be672_row0_col11, #T_be672_row1_col0, #T_be672_row1_col1, #T_be672_row1_col2, #T_be672_row1_col3, #T_be672_row1_col4, #T_be672_row1_col5, #T_be672_row1_col6, #T_be672_row1_col7, #T_be672_row1_col8, #T_be672_row1_col9, #T_be672_row1_col10, #T_be672_row1_col11, #T_be672_row2_col0, #T_be672_row2_col1, #T_be672_row2_col2, #T_be672_row2_col3, #T_be672_row2_col4, #T_be672_row2_col5, #T_be672_row2_col6, #T_be672_row2_col7, #T_be672_row2_col8, #T_be672_row2_col9, #T_be672_row2_col10, #T_be672_row2_col11 {
#   text-align: left;
# }
# </style>
# <table id="T_be672">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be672_level0_col0" class="col_heading level0 col0" >total_texts</th>
#       <th id="T_be672_level0_col1" class="col_heading level0 col1" >texts_with_quote</th>
#       <th id="T_be672_level0_col2" class="col_heading level0 col2" >texts_with_said_q</th>
#       <th id="T_be672_level0_col3" class="col_heading level0 col3" >sum_quote</th>
#       <th id="T_be672_level0_col4" class="col_heading level0 col4" >sum_said_q</th>
#       <th id="T_be672_level0_col5" class="col_heading level0 col5" >sum_quote_words</th>
#       <th id="T_be672_level0_col6" class="col_heading level0 col6" >sum_said_q_words</th>
#       <th id="T_be672_level0_col7" class="col_heading level0 col7" >sum_total_words</th>
#       <th id="T_be672_level0_col8" class="col_heading level0 col8" >pct_quote</th>
#       <th id="T_be672_level0_col9" class="col_heading level0 col9" >pct_said_q</th>
#       <th id="T_be672_level0_col10" class="col_heading level0 col10" >pct_words_in_quote</th>
#       <th id="T_be672_level0_col11" class="col_heading level0 col11" >pct_words_in_said_q</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >genre</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be672_level0_row0" class="row_heading level0 row0" >mixed</th>
#       <td id="T_be672_row0_col0" class="data row0 col0" >94</td>
#       <td id="T_be672_row0_col1" class="data row0 col1" >56</td>
#       <td id="T_be672_row0_col2" class="data row0 col2" >49</td>
#       <td id="T_be672_row0_col3" class="data row0 col3" >2,167</td>
#       <td id="T_be672_row0_col4" class="data row0 col4" >5,775</td>
#       <td id="T_be672_row0_col5" class="data row0 col5" >25,872</td>
#       <td id="T_be672_row0_col6" class="data row0 col6" >311,057</td>
#       <td id="T_be672_row0_col7" class="data row0 col7" >1,889,826</td>
#       <td id="T_be672_row0_col8" class="data row0 col8" >59.6%</td>
#       <td id="T_be672_row0_col9" class="data row0 col9" >52.1%</td>
#       <td id="T_be672_row0_col10" class="data row0 col10" >1.4%</td>
#       <td id="T_be672_row0_col11" class="data row0 col11" >16.5%</td>
#     </tr>
#     <tr>
#       <th id="T_be672_level0_row1" class="row_heading level0 row1" >poetry</th>
#       <td id="T_be672_row1_col0" class="data row1 col0" >160</td>
#       <td id="T_be672_row1_col1" class="data row1 col1" >23</td>
#       <td id="T_be672_row1_col2" class="data row1 col2" >63</td>
#       <td id="T_be672_row1_col3" class="data row1 col3" >3,911</td>
#       <td id="T_be672_row1_col4" class="data row1 col4" >3,851</td>
#       <td id="T_be672_row1_col5" class="data row1 col5" >74,850</td>
#       <td id="T_be672_row1_col6" class="data row1 col6" >161,599</td>
#       <td id="T_be672_row1_col7" class="data row1 col7" >1,620,737</td>
#       <td id="T_be672_row1_col8" class="data row1 col8" >14.4%</td>
#       <td id="T_be672_row1_col9" class="data row1 col9" >39.4%</td>
#       <td id="T_be672_row1_col10" class="data row1 col10" >4.6%</td>
#       <td id="T_be672_row1_col11" class="data row1 col11" >10.0%</td>
#     </tr>
#     <tr>
#       <th id="T_be672_level0_row2" class="row_heading level0 row2" >prose</th>
#       <td id="T_be672_row2_col0" class="data row2 col0" >1198</td>
#       <td id="T_be672_row2_col1" class="data row2 col1" >313</td>
#       <td id="T_be672_row2_col2" class="data row2 col2" >320</td>
#       <td id="T_be672_row2_col3" class="data row2 col3" >18,920</td>
#       <td id="T_be672_row2_col4" class="data row2 col4" >34,677</td>
#       <td id="T_be672_row2_col5" class="data row2 col5" >447,511</td>
#       <td id="T_be672_row2_col6" class="data row2 col6" >847,068</td>
#       <td id="T_be672_row2_col7" class="data row2 col7" >26,564,212</td>
#       <td id="T_be672_row2_col8" class="data row2 col8" >26.1%</td>
#       <td id="T_be672_row2_col9" class="data row2 col9" >26.7%</td>
#       <td id="T_be672_row2_col10" class="data row2 col10" >1.7%</td>
#       <td id="T_be672_row2_col11" class="data row2 col11" >3.2%</td>
#     </tr>
#   </tbody>
# </table>
# Saved: 04_quotation_tags_by_century.png

# %%
# ── Greek works with no English translation file ──
# For each Greek edition, check whether a sibling file with "-eng" exists
# in the same work directory.  Display an interactive sortable table.

from IPython.display import display, HTML

def find_missing_translations(df):
    """For each Greek file, check if an English translation exists in the same directory."""
    records = []
    seen_dirs = {}

    for _, row in df.iterrows():
        if row['repo'] == 'Perseus':
            base = REPOS['perseus']['dir']
        else:
            base = REPOS['first1k']['dir']

        # Locate the Greek file
        matches = glob.glob(os.path.join(base, 'data', '**', row['file']), recursive=True)
        if not matches:
            continue
        grc_path = matches[0]
        work_dir = os.path.dirname(grc_path)

        # Check once per directory whether any "-eng" file exists
        if work_dir not in seen_dirs:
            siblings = os.listdir(work_dir)
            seen_dirs[work_dir] = any(
                'eng' in f.lower() and f.endswith('.xml') for f in siblings
            )

        has_eng = seen_dirs[work_dir]
        records.append({
            'author': row['author'],
            'file': row['file'],
            'repo': row['repo'],
            'tlg_code': row['tlg_code'],
            'century': row.get('century'),
            'century_label': row.get('century_label', ''),
            'genre': row['genre'],
            'word_count': row['word_count'],
            'has_eng': has_eng,
        })

    return pd.DataFrame(records)

print("Checking for English translations...")
df_trans = find_missing_translations(df[df['word_count'] > 0])

df_no_eng = df_trans[~df_trans['has_eng']].copy()
df_no_eng = df_no_eng.sort_values('word_count', ascending=False).reset_index(drop=True)

total_grc = len(df_trans)
n_with = df_trans['has_eng'].sum()
n_without = total_grc - n_with
words_without = df_no_eng['word_count'].sum()

print(f"\nGreek editions checked   : {total_grc:,}")
print(f"  With English translation : {n_with:,}  ({n_with/total_grc*100:.1f}%)")
print(f"  Without                  : {n_without:,}  ({n_without/total_grc*100:.1f}%)")
print(f"  Untranslated word total  : {words_without:,}\n")

# ── Sortable HTML table ──
# Uses a small JS snippet so you can click column headers to sort.
def sortable_table(df_display, title=""):
    """Render a DataFrame as a sortable HTML table (click headers to sort)."""
    table_id = "tbl_no_eng"
    rows_html = ""
    for _, r in df_display.iterrows():
        rows_html += (
            f"<tr>"
            f"<td>{r['author']}</td>"
            f"<td>{r['file']}</td>"
            f"<td>{r['repo']}</td>"
            f"<td style='text-align:right'>{r['word_count']:,}</td>"
            f"<td>{r['century_label']}</td>"
            f"<td>{r['genre']}</td>"
            f"</tr>\n"
        )

    html = f"""
    <h3>{title}</h3>
    <p style="color:#666; font-size:0.9em;">Click any column header to sort.</p>
    <table id="{table_id}" style="border-collapse:collapse; font-size:0.85em; width:100%;">
    <thead>
      <tr style="background:#f0f0f0; cursor:pointer;">
        <th onclick="sortTable('{table_id}',0,'str')">Author ⇅</th>
        <th onclick="sortTable('{table_id}',1,'str')">File ⇅</th>
        <th onclick="sortTable('{table_id}',2,'str')">Repo ⇅</th>
        <th onclick="sortTable('{table_id}',3,'num')" style="text-align:right">Word count ⇅</th>
        <th onclick="sortTable('{table_id}',4,'str')">Century ⇅</th>
        <th onclick="sortTable('{table_id}',5,'str')">Genre ⇅</th>
      </tr>
    </thead>
    <tbody>
    {rows_html}
    </tbody>
    </table>
    <script>
    var sortDirs = {{}};
    function sortTable(id, col, typ) {{
        var table = document.getElementById(id);
        var tbody = table.querySelector('tbody');
        var rows = Array.from(tbody.querySelectorAll('tr'));
        var key = id + '_' + col;
        sortDirs[key] = !sortDirs[key];
        var asc = sortDirs[key];
        rows.sort(function(a, b) {{
            var av = a.children[col].textContent.trim();
            var bv = b.children[col].textContent.trim();
            if (typ === 'num') {{
                av = parseFloat(av.replace(/,/g, '')) || 0;
                bv = parseFloat(bv.replace(/,/g, '')) || 0;
                return asc ? av - bv : bv - av;
            }}
            return asc ? av.localeCompare(bv) : bv.localeCompare(av);
        }});
        rows.forEach(function(r) {{ tbody.appendChild(r); }});
    }}
    </script>
    <style>
    #{table_id} td, #{table_id} th {{ padding: 4px 8px; border-bottom: 1px solid #ddd; }}
    #{table_id} tbody tr:hover {{ background: #f8f8e8; }}
    </style>
    """
    display(HTML(html))

sortable_table(df_no_eng,
               title=f"Greek editions without an English translation ({n_without:,} works, {words_without:,} words)")
# Out:
# Checking for English translations...
#
# Greek editions checked   : 1,932
#   With English translation : 674  (34.9%)
#   Without                  : 1,258  (65.1%)
#   Untranslated word total  : 28,355,820
#     <h3>Greek editions without an English translation (1,258 works, 28,355,820 words)</h3>
#     <p style="color:#666; font-size:0.9em;">Click any column header to sort.</p>
#     <table id="tbl_no_eng" style="border-collapse:collapse; font-size:0.85em; width:100%;">
#     <thead>
#       <tr style="background:#f0f0f0; cursor:pointer;">
#         <th onclick="sortTable('tbl_no_eng',0,'str')">Author ⇅</th>
#         <th onclick="sortTable('tbl_no_eng',1,'str')">File ⇅</th>
#         <th onclick="sortTable('tbl_no_eng',2,'str')">Repo ⇅</th>
#         <th onclick="sortTable('tbl_no_eng',3,'num')" style="text-align:right">Word count ⇅</th>
#         <th onclick="sortTable('tbl_no_eng',4,'str')">Century ⇅</th>
#         <th onclick="sortTable('tbl_no_eng',5,'str')">Genre ⇅</th>
#       </tr>
#     </thead>
#     <tbody>
#     <tr><td>Scholia in Homerum</td><td>tlg5026.tlg001.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>755,269</td><td></td><td>prose</td></tr>
# <tr><td>Suda</td><td>tlg9010.tlg001.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>583,818</td><td></td><td>prose</td></tr>
# <tr><td>Simplicius</td><td>tlg4013.tlg004.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>493,594</td><td></td><td>prose</td></tr>
# <tr><td>Alexander of Aphrodisias</td><td>tlg0732.tlg004.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>387,770</td><td></td><td>prose</td></tr>
# <tr><td>John Philoponus</td><td>tlg4015.tlg009.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>368,933</td><td></td><td>prose</td></tr>
# <tr><td>Cyril of Alexandria</td><td>tlg4090.tlg001.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>357,860</td><td></td><td>prose</td></tr>
# <tr><td>Joannes Zonaras</td><td>tlg3135.tlg001.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>347,954</td><td></td><td>prose</td></tr>
# <tr><td>Simplicius</td><td>tlg4013.tlg001.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>311,570</td><td></td><td>prose</td></tr>
# <tr><td>Dionysius of Halicarnassus</td><td>tlg0081.tlg001.perseus-grc2.xml</td><td>Perseus</td><td style='text-align:right'>284,276</td><td></td><td>prose</td></tr>
# <tr><td>Eustratius</td><td>tlg4031.tlg002.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>264,213</td><td></td><td>prose</td></tr>
# <tr><td>John Philoponus</td><td>tlg4015.tlg008.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>258,365</td><td></td><td>prose</td></tr>
# <tr><td>Alexander of Aphrodisias</td><td>tlg0732.tlg006.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>240,023</td><td></td><td>prose</td></tr>
# <tr><td>Epiphanius</td><td>tlg2021.tlg002.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>236,810</td><td></td><td>prose</td></tr>
# <tr><td>Eusebius</td><td>tlg2018.tlg001.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>230,002</td><td></td><td>mixed</td></tr>
# <tr><td>Procopius</td><td>tlg4029.tlg001.perseus-grc2.xml</td><td>Perseus</td><td style='text-align:right'>224,548</td><td></td><td>prose</td></tr>
# <tr><td>Claudius Ptolemaeus</td><td>tlg0363.tlg001.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>219,381</td><td></td><td>prose</td></tr>
# <tr><td>Plotinus</td><td>tlg2000.tlg001.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>214,015</td><td></td><td>prose</td></tr>
# <tr><td>Simplicius</td><td>tlg4013.tlg003.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>194,496</td><td></td><td>prose</td></tr>
# <tr><td>Galen</td><td>tlg0057.tlg017.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>194,297</td><td></td><td>prose</td></tr>
# <tr><td>Cassius Dio Cocceianus</td><td>tlg0385.tlg001.perseus-grc2.xml</td><td>Perseus</td><td style='text-align:right'>191,358</td><td></td><td>prose</td></tr>
# <tr><td>Scholia in Homerum</td><td>tlg5026.tlg007.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>191,068</td><td></td><td>prose</td></tr>
# <tr><td>Asclepius</td><td>tlg4018.tlg001.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>190,402</td><td></td><td>prose</td></tr>
# <tr><td>John Philoponus</td><td>tlg4015.tlg002.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>188,454</td><td></td><td>prose</td></tr>
# <tr><td>Diodorus Siculus</td><td>tlg0060.tlg001.perseus-grc4.xml</td><td>Perseus</td><td style='text-align:right'>182,985</td><td></td><td>prose</td></tr>
# <tr><td>Alexander of Aphrodisias</td><td>tlg0732.tlg005.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>178,764</td><td></td><td>prose</td></tr>
# <tr><td>Dio Chrysostom</td><td>tlg0612.tlg001.perseus-grc2.xml</td><td>Perseus</td><td style='text-align:right'>178,358</td><td></td><td>prose</td></tr>
# <tr><td>Proclus Diadochus</td><td>tlg4036.tlg001.opp-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>175,197</td><td></td><td>prose</td></tr>
# <tr><td>Dioscurides Pedianus</td><td>tlg0656.tlg001.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>170,756</td><td></td><td>prose</td></tr>
# <tr><td>John Philoponus</td><td>tlg4015.tlg004.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>167,946</td><td></td><td>prose</td></tr>
# <tr><td>Sextus Empiricus</td><td>tlg0544.tlg002.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>166,029</td><td></td><td>prose</td></tr>
# <tr><td>Origenes</td><td>tlg2042.tlg001.perseus-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>164,895</td><td></td><td>prose</td></tr>
# <tr><td>Origenes</td><td>tlg2042.tlg005.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>163,583</td><td></td><td>prose</td></tr>
# <tr><td>Anna Comnena</td><td>tlg2703.tlg001.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>162,386</td><td></td><td>prose</td></tr>
# <tr><td>Libanius</td><td>tlg2200.tlg001.opp-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>157,570</td><td></td><td>prose</td></tr>
# <tr><td>Galen</td><td>tlg0057.tlg066.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>157,546</td><td></td><td>prose</td></tr>
# <tr><td>Eusebius</td><td>tlg2018.tlg005.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>156,444</td><td></td><td>prose</td></tr>
# <tr><td>Galen</td><td>tlg0057.tlg089.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>156,383</td><td></td><td>prose</td></tr>
# <tr><td>Catenae (Novum Testamentum)</td><td>tlg4102.tlg038.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>153,061</td><td></td><td>prose</td></tr>
# <tr><td>Annae Comnenae</td><td>tlg2703.tlg001.1st1K-grc2.xml</td><td>First1KGreek</td><td style='text-align:right'>150,778</td><td></td><td>prose</td></tr>
# <tr><td>Scholia in Euripidem</td><td>tlg5023.tlg001.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>143,985</td><td></td><td>prose</td></tr>
# <tr><td>Galen</td><td>tlg0057.tlg076.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>142,666</td><td></td><td>mixed</td></tr>
# <tr><td>Simplicius</td><td>tlg4013.tlg005.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>141,111</td><td></td><td>prose</td></tr>
# <tr><td>Basil, Saint, Bishop of Caesarea</td><td>tlg2040.tlg004.perseus-grc2.xml</td><td>Perseus</td><td style='text-align:right'>136,837</td><td></td><td>prose</td></tr>
# <tr><td>Aelius Herodianus</td><td>tlg0087.tlg001.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>136,723</td><td></td><td>prose</td></tr>
# <tr><td>Galen</td><td>tlg0057.tlg075.1st1K-grc1.xml</td><td>First1KGreek</td><td style='text-align:right'>133,890</td><td></td><td>prose</td></tr>
# <tr><td>Clement of Alexandria</td><td>tlg0555.tlg004.perseus-grc1.xml</td><td>Perseus</td><td style='text-align:right'>133,497</td><td></td><td>prose</td></tr>
# <tr><td>Chronicon Paschale</td><td>
